# %% [markdown]
# # Disclaimer
#
# Funktioniert nicht mit den hier benutzten Versionen der Bibliotheken, wurde in einem anderen Python environment ausgeführt (requirements_alt)

# %%
import numpy as np
import random 
import gym

import tensorflow as tf
#tf.enable_eager_execution()
import numpy as np
import pandas as pd

from matplotlib.colors import LogNorm
import matplotlib.pyplot as plt

# %%
# seed random number generators for reproducable results
np.random.seed (0)
random.seed(0)
tf.set_random_seed(0)
#tf.random.set_seed(0)
# Out:
# WARNING:tensorflow:From C:\Users\gulBa\AppData\Local\Temp\ipykernel_16676\1296988684.py:4: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.

# %% [markdown]
# # SAMPLE DATA

# %%
# for details see: https://github.com/openai/gym/blob/master/gym/envs/classic_control/cartpole.py
CART_POS="cartPos"
CART_VEL="cartVel"
PEND_POS="pendPos"
PEND_VEL="pendVel"
EPISODE="episode"
STEP="step"
ACTION="action"
    
def sample_data (episodes=10000, masscart=1.0, masspole=0.1, length=0.5, tau=0.02, seed=0):
    env = gym.make("CartPole-v1")
    env.np_random.seed(0)

    # Modify the environment parameters
    env.env.masscart = masscart
    env.env.masspole = masspole
    env.env.length = length
    env.env.tau = tau
    
    ### CREATE EMPTY Pandas dataset
    transitions = []

    ### SAMPLE DATA
    for episode in range (episodes):
        #print ("Start of episode %d" % episode)
        obs = env.reset()
        step =0
        done = False

        while step < 500 and not done:
            step += 1
            action = env.action_space.sample()

            transitions.append({CART_POS:obs[0], CART_VEL:obs[1], 
                             PEND_POS:obs[2], PEND_VEL:obs[3],
                             EPISODE:episode, STEP:step, ACTION:action})

            obs, reward, done, _ = env.step(action)

        #print ("  --> finished after %d steps" % step)
        
    return pd.DataFrame(transitions)


df = sample_data (episodes=10000, seed=0)

# %%
#plt.hist2d(, bins=(50, 50), cmap=plt.cm.Reds)
h = plt.hist2d(df[CART_POS], df[PEND_POS], bins=40, norm=LogNorm())
plt.colorbar(h[3])
plt.grid()
plt.xlabel ("Cart position")
plt.ylabel ("Pendulum position")
plt.show()

# %%
df.plot(subplots=True, figsize=(10,15), grid=True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %% [markdown]
# # Generate pattern data

# %%
#############################################
#### HELPER FUNCTIONS FOR PATTERN GENERATION
#############################################
def create_training_data(data, input_col, target_col, window_size=1, training_pattern_percent=0.7):

    data_train = data

    mean_in, std_in = mean_and_std(input_col, data_train)
    mean_out, std_out = mean_and_std(target_col, data_train)
    #data_plot.plot_hist_df(data_train, input_col)
    #data_plot.plot_timeseries_df(data_train, input_col)
    print(f"mean in = {mean_in}" )
    print(f"std in = {std_in}")
    print(f"mean out =  {mean_out}")
    print(f"std out = {std_out}")

    grouped = data_train.groupby(['episode'])

    inputs_all = []
    labels_all = []

    for g in grouped:
        # be sure that data inside a group is not shuffled # not sure if needed
        g = g[1].sort_values(by='step')

        past_history = window_size   # t-3, t-2, t-1, t
        future_target = 0  # t+1
        STEP = 1 # no subsampling of rows in data, e.g. only every i'th row

        # use pandas.DataFrame.values in order to get an numpy array from an pandas.DataFrame object

        inputs, labels = multivariate_data(dataset=g[input_col][:].values, target=g[target_col][:].values,
                                        start_index=0, end_index=g[input_col][:].values.shape[0]-future_target,
                                        history_size=past_history, target_size=future_target, step=STEP,
                                        single_step=True)

        ## Append data to whole set of patterns
        for i in range (0, len(inputs)):
            inputs_all.append(inputs[i])
            labels_all.append(labels[i])
  
    length = len(inputs_all)

    c = list(zip(inputs_all, labels_all))
    np.random.shuffle(c)
    inputs_all, labels_all = zip(*c)

    split = int(training_pattern_percent * length)

    inputs_all = np.array(inputs_all)
    labels_all = np.array(labels_all)

    return ((inputs_all[0:split], labels_all[0:split]), (inputs_all[split:], labels_all[split:])), mean_in, std_in, mean_out, std_out


def mean_and_std(columns, data):
    mean = np.zeros(len(columns))
    std = np.zeros(len(columns))
    index = 0
    for c in columns:
        mean[index], std[index] = get_normalizations(data[c])
        index = index + 1
    return mean, std

def get_normalizations(data):
    mean = data.mean()
    std = data.std()
    return mean, std

def multivariate_data(dataset, target, start_index, end_index, history_size,
                      target_size, step, single_step=False):
    data = []
    labels = []

    start_index = start_index + history_size
    if end_index is None:
       end_index = len(dataset) - target_size

    for i in range(start_index, end_index):
        indices = range(i-history_size, i, step)
        data.append(dataset[indices])

        if single_step:
            labels.append(target[i+target_size])
        else:
            labels.append(target[i:i+target_size])

    return np.array(data, dtype=np.float32), np.array(labels, dtype=np.float32)



def prepare_data(df, input_col, target_col, window_size, training_batch_size=50, validation_batch_size=50, training_pattern_percent=0.7):
    
    global x_train_multi, y_train_multi
    
    ###################
    ## PREPARE DATASET
    ###################
    ((x_train_multi, y_train_multi), (x_val_multi, y_val_multi)), mean_in, std_in, mean_out, std_out = \
                                    create_training_data(df, input_col, target_col, window_size=window_size,
                                                        training_pattern_percent=training_pattern_percent)

    print('trainData: Single window of past history : {}'.format(x_train_multi[0].shape))
    print('trainData: Single window of future : {}'.format(y_train_multi[1].shape))
    print('valData: Single window of past history : {}'.format(x_val_multi[0].shape))
    print('valData: Single window of future : {}'.format(y_val_multi[1].shape))
    print('trainData: number of trainingsexamples: {}'.format(x_train_multi.shape))
    print('valData: number of trainingsexamples: {}'.format(x_val_multi.shape))

    train_data = tf.data.Dataset.from_tensor_slices((x_train_multi, y_train_multi))
    #train_data = train_data.cache().shuffle(max_training_pattern).batch(training_batch_size).repeat()
    train_data = train_data.shuffle(x_train_multi.shape[0]).batch(training_batch_size).repeat()

    val_data = tf.data.Dataset.from_tensor_slices((x_val_multi, y_val_multi))
    val_data = val_data.batch(validation_batch_size).repeat()
    input_shape = x_train_multi[0].shape[-2:]
    return train_data, val_data, input_shape, mean_in, std_in, mean_out, std_out

# %%
window_size=4
input_col = [CART_POS, CART_VEL, PEND_POS, PEND_VEL, ACTION]
target_col = [CART_POS, CART_VEL, PEND_POS, PEND_VEL]

train_data, val_data, input_shape, mean_in, std_in, mean_out, std_out =  \
            prepare_data(df, input_col, target_col, window_size=window_size, training_pattern_percent=0.7)

print ("Input-Shape: ", input_shape)
# Out:
# mean in = [-6.64914327e-04 -5.23430254e-03 -1.09184192e-04  6.37533698e-03
#   4.98915059e-01]
# std in = [0.09621819 0.53671445 0.09189725 0.78745017 0.49999995]
# mean out =  [-0.00066491 -0.0052343  -0.00010918  0.00637534]
# std out = [0.09621819 0.53671445 0.09189725 0.78745017]
# trainData: Single window of past history : (4, 5)
# trainData: Single window of future : (4,)
# valData: Single window of past history : (4, 5)
# valData: Single window of future : (4,)
# trainData: number of trainingsexamples: (127169, 4, 5)
# valData: number of trainingsexamples: (54502, 4, 5)
# WARNING:tensorflow:From c:\Users\gulBa\CodingProjects\reinforcement-learning-project\TimeSeriesTransformer\.venv\lib\site-packages\tensorflow_core\python\data\util\random_seed.py:58: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Input-Shape:  (4, 5)

# %% [markdown]
# # Create Cartpole state-transition model

# %%
def build_single_step_model(mean_in, std_in, mean_out, std_out, input_shape, optimizer=tf.keras.optimizers.RMSprop()):

    print(f"mean = {mean_in}, std = {std_in}, mean = {mean_out}, std = {std_out}")
    single_step_model = tf.keras.models.Sequential()
        
    single_step_model.add(tf.keras.layers.Lambda(lambda x: (x - mean_in) / std_in, input_shape=input_shape)) #, dtype=np.float32))
    #single_step_model.add(tf.keras.layers.Flatten())
    #single_step_model.add(tf.keras.layers.Dense(20, activation="sigmoid"))
    single_step_model.add(tf.keras.layers.LSTM(50, input_shape=input_shape, dtype=np.float32))
    single_step_model.add(tf.keras.layers.Dense(len(mean_out), activation="linear"))

    single_step_model.compile(optimizer=optimizer, loss="mse")

    return single_step_model

# %% [markdown]
# # V2 Transformer Model

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, LayerNormalization, Input
from tensorflow.keras.models import Model

class MultiHeadAttention(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads):
        super(MultiHeadAttention, self).__init__()
        self.num_heads = num_heads
        self.d_model = d_model

        assert d_model % self.num_heads == 0

        self.depth = d_model // self.num_heads

        self.wq = tf.keras.layers.Dense(d_model)
        self.wk = tf.keras.layers.Dense(d_model)
        self.wv = tf.keras.layers.Dense(d_model)

        self.dense = tf.keras.layers.Dense(d_model)

    def split_heads(self, x, batch_size):
        """Split the last dimension into (num_heads, depth).
        Transpose the result such that the shape is (batch_size, num_heads, seq_len, depth)
        """
        x = tf.reshape(x, (batch_size, -1, self.num_heads, self.depth))
        return tf.transpose(x, perm=[0, 2, 1, 3])

    def call(self, v, k, q):
        batch_size = tf.shape(q)[0]

        q = self.split_heads(self.wq(q), batch_size)
        k = self.split_heads(self.wk(k), batch_size)
        v = self.split_heads(self.wv(v), batch_size)

        scaled_attention, _ = scaled_dot_product_attention(q, k, v)

        scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])
        concat_attention = tf.reshape(scaled_attention, (batch_size, -1, self.d_model))

        output = self.dense(concat_attention)

        return output

def scaled_dot_product_attention(q, k, v, mask=None):
    """Calculate the attention weights."""
    matmul_qk = tf.matmul(q, k, transpose_b=True)

    dk = tf.cast(tf.shape(k)[-1], tf.float32)
    scaled_attention_logits = matmul_qk / tf.math.sqrt(dk)

    if mask is not None:
        scaled_attention_logits += (mask * -1e9)

    attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1)
    output = tf.matmul(attention_weights, v)

    return output, attention_weights

# Positional Encoding
def get_angles(pos, i, d_model):
    angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
    return pos * angle_rates

def positional_encoding(position, d_model):
    angle_rads = get_angles(np.arange(position)[:, np.newaxis],
                            np.arange(d_model)[np.newaxis, :],
                            d_model)
    
    angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
    angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
    
    pos_encoding = angle_rads[np.newaxis, ...]
    return tf.cast(pos_encoding, dtype=tf.float32)




class EncoderLayer(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads, dff, rate=0.1):
        super(EncoderLayer, self).__init__()

        self.mha = MultiHeadAttention(d_model, num_heads)
        self.ffn = tf.keras.Sequential([
            tf.keras.layers.Dense(dff, activation='relu'),
            tf.keras.layers.Dense(d_model)
        ])

        self.layernorm1 = LayerNormalization(epsilon=1e-6)
        self.layernorm2 = LayerNormalization(epsilon=1e-6)

        self.dropout1 = Dropout(rate)
        self.dropout2 = Dropout(rate)

    def call(self, x, training):
        attn_output = self.mha(x, x, x)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(x + attn_output)

        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        out2 = self.layernorm2(out1 + ffn_output)

        return out2

class Encoder(tf.keras.layers.Layer):
    def __init__(self, num_layers, d_model, num_heads, dff, input_shape, rate=0.1):
        super(Encoder, self).__init__()

        self.d_model = d_model
        self.num_layers = num_layers

        self.embedding = Dense(d_model)
        self.pos_encoding = positional_encoding(input_shape[0], d_model)

        self.enc_layers = [EncoderLayer(d_model, num_heads, dff, rate) for _ in range(num_layers)]
        self.dropout = Dropout(rate)

    def call(self, x, training, mask=None):
        seq_len = tf.shape(x)[1]
        
        x = self.embedding(x)
        x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
        x += self.pos_encoding[:, :seq_len, :]
        x = self.dropout(x, training=training)
        for i in range(self.num_layers):
            x = self.enc_layers[i](x, training)
        
        return x


class TimeSeriesTransformer(tf.keras.Model):
    def __init__(self, num_layers, d_model, num_heads, dff, input_shape, output_dim, rate=0.1):
        super(TimeSeriesTransformer, self).__init__()
        self.encoder = Encoder(num_layers, d_model, num_heads, dff, input_shape, rate)
        self.final_layer = Dense(output_dim)

    def call(self, x, training=False):
        mask = None  # Implement masking logic here if needed
        enc_output = self.encoder(x, training, mask)
        final_output = self.final_layer(enc_output[:, -1])
        return final_output

def build_transformer_model(mean_in, std_in, mean_out, std_out, input_shape, num_layers=2, d_model=64, num_heads=4, dff=256, rate=0.1):
    input_dim = input_shape[-1]
    output_dim = len(mean_out)
    transformer = TimeSeriesTransformer(num_layers, d_model, num_heads, dff, input_shape, output_dim, rate)

    inputs = Input(shape=input_shape)
    x = tf.keras.layers.Lambda(lambda x: (x - mean_in) / std_in)(inputs)  # Normalization
    outputs = transformer(x)

    # model = Model(inputs=inputs, outputs=outputs)
    model = TimeSeriesTransformer(num_layers, d_model, num_heads, dff, input_shape, output_dim, rate)
    model.compile(optimizer=tf.train.AdamOptimizer(), loss='mse')
    return model

# %% [markdown]
# ## LSTM

# %%
import os
modelpath="lstm_model"
if not os.path.exists(modelpath):
    os.makedirs(modelpath)
max_epochs=1000
steps_per_epoch = 100
validation_steps = 100
validation_freq = 1

es_callback = tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, restore_best_weights=True, verbose=True)
mc_trainLoss_callback = tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(modelpath, "model_bestTrainLoss"), monitor='loss', verbose=1, save_best_only=True, mode=min)
mc_valLoss_callback = tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(modelpath, "model_bestValLoss"), monitor='val_loss', verbose=1, save_best_only=True, mode=min)
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir = ".\model_logs_tb", histogram_freq=1)


model = build_single_step_model(mean_in, std_in, mean_out, std_out, input_shape)
history = model.fit(train_data, epochs=max_epochs, steps_per_epoch=steps_per_epoch,
                        validation_data=val_data, validation_steps=validation_steps, validation_freq=validation_freq,
                        callbacks=[mc_trainLoss_callback, mc_valLoss_callback, es_callback, tensorboard_callback])
model.save(os.path.join(modelpath, 'lstm_model'))
# Out:
# WARNING:tensorflow:ModelCheckpoint mode <built-in function min> is unknown, fallback to auto mode.
# WARNING:tensorflow:ModelCheckpoint mode <built-in function min> is unknown, fallback to auto mode.
# mean = [-6.64914327e-04 -5.23430254e-03 -1.09184192e-04  6.37533698e-03
#   4.98915059e-01], std = [0.09621819 0.53671445 0.09189725 0.78745017 0.49999995], mean = [-0.00066491 -0.0052343  -0.00010918  0.00637534], std = [0.09621819 0.53671445 0.09189725 0.78745017]
# WARNING:tensorflow:From c:\Users\gulBa\CodingProjects\reinforcement-learning-project\TimeSeriesTransformer\.venv\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Train on 100 steps, validate on 100 steps
# Epoch 1/1000
#  94/100 [===========================>..] - ETA: 0s - loss: 0.0505
# Epoch 00001: loss improved from inf to 0.04772, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00001: val_loss improved from inf to 0.00356, saving model to lstm_model\model_bestValLoss
# 100/100 [==============================] - 1s 14ms/step - loss: 0.0477 - val_loss: 0.0036
# Epoch 2/1000
#  98/100 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 00002: loss improved from 0.04772 to 0.00143, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00002: val_loss improved from 0.00356 to 0.00054, saving model to lstm_model\model_bestValLoss
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0014 - val_loss: 5.4078e-04
# Epoch 3/1000
#  86/100 [========================>.....] - ETA: 0s - loss: 5.2015e-04
# Epoch 00003: loss improved from 0.00143 to 0.00051, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00003: val_loss improved from 0.00054 to 0.00025, saving model to lstm_model\model_bestValLoss
# 100/100 [==============================] - 0s 5ms/step - loss: 5.1212e-04 - val_loss: 2.5452e-04
# Epoch 4/1000
#  97/100 [============================>.] - ETA: 0s - loss: 3.6036e-04
# Epoch 00004: loss improved from 0.00051 to 0.00035, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00004: val_loss improved from 0.00025 to 0.00022, saving model to lstm_model\model_bestValLoss
# 100/100 [==============================] - 1s 5ms/step - loss: 3.5440e-04 - val_loss: 2.2124e-04
# Epoch 5/1000
#  94/100 [===========================>..] - ETA: 0s - loss: 2.6766e-04
# Epoch 00005: loss improved from 0.00035 to 0.00027, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00005: val_loss did not improve from 0.00022
# 100/100 [==============================] - 1s 5ms/step - loss: 2.6598e-04 - val_loss: 3.3928e-04
# Epoch 6/1000
#  85/100 [========================>.....] - ETA: 0s - loss: 2.0231e-04
# Epoch 00006: loss improved from 0.00027 to 0.00020, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00006: val_loss improved from 0.00022 to 0.00013, saving model to lstm_model\model_bestValLoss
# 100/100 [==============================] - 0s 5ms/step - loss: 1.9858e-04 - val_loss: 1.2980e-04
# Epoch 7/1000
#  90/100 [==========================>...] - ETA: 0s - loss: 1.9358e-04
# Epoch 00007: loss improved from 0.00020 to 0.00019, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00007: val_loss did not improve from 0.00013
# 100/100 [==============================] - 0s 4ms/step - loss: 1.9149e-04 - val_loss: 6.7816e-04
# Epoch 8/1000
#  90/100 [==========================>...] - ETA: 0s - loss: 1.8910e-04
# Epoch 00008: loss improved from 0.00019 to 0.00018, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00008: val_loss did not improve from 0.00013
# 100/100 [==============================] - 0s 4ms/step - loss: 1.7813e-04 - val_loss: 2.5069e-04
# Epoch 9/1000
#  89/100 [=========================>....] - ETA: 0s - loss: 1.5804e-04
# Epoch 00009: loss improved from 0.00018 to 0.00016, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00009: val_loss did not improve from 0.00013
# 100/100 [==============================] - 0s 5ms/step - loss: 1.6034e-04 - val_loss: 3.8926e-04
# Epoch 10/1000
#  98/100 [============================>.] - ETA: 0s - loss: 1.5905e-04
# Epoch 00010: loss improved from 0.00016 to 0.00016, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00010: val_loss improved from 0.00013 to 0.00008, saving model to lstm_model\model_bestValLoss
# 100/100 [==============================] - 0s 5ms/step - loss: 1.5985e-04 - val_loss: 7.6032e-05
# Epoch 11/1000
#  90/100 [==========================>...] - ETA: 0s - loss: 1.5975e-04
# Epoch 00011: loss did not improve from 0.00016
#
# Epoch 00011: val_loss did not improve from 0.00008
# 100/100 [==============================] - 0s 4ms/step - loss: 1.6051e-04 - val_loss: 1.1679e-04
# Epoch 12/1000
#  87/100 [=========================>....] - ETA: 0s - loss: 1.5024e-04
# Epoch 00012: loss improved from 0.00016 to 0.00014, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00012: val_loss improved from 0.00008 to 0.00003, saving model to lstm_model\model_bestValLoss
# 100/100 [==============================] - 0s 5ms/step - loss: 1.4296e-04 - val_loss: 2.6791e-05
# Epoch 13/1000
#  90/100 [==========================>...] - ETA: 0s - loss: 1.4450e-04
# Epoch 00013: loss did not improve from 0.00014
#
# Epoch 00013: val_loss did not improve from 0.00003
# 100/100 [==============================] - 0s 4ms/step - loss: 1.4783e-04 - val_loss: 4.5677e-05
# Epoch 14/1000
#  89/100 [=========================>....] - ETA: 0s - loss: 1.3773e-04
# Epoch 00014: loss improved from 0.00014 to 0.00014, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00014: val_loss improved from 0.00003 to 0.00003, saving model to lstm_model\model_bestValLoss
# 100/100 [==============================] - 0s 5ms/step - loss: 1.3713e-04 - val_loss: 2.5155e-05
# Epoch 15/1000
#  98/100 [============================>.] - ETA: 0s - loss: 1.2611e-04
# Epoch 00015: loss improved from 0.00014 to 0.00012, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00015: val_loss did not improve from 0.00003
# 100/100 [==============================] - 0s 5ms/step - loss: 1.2414e-04 - val_loss: 3.7555e-05
# Epoch 16/1000
#  89/100 [=========================>....] - ETA: 0s - loss: 1.3227e-04
# Epoch 00016: loss did not improve from 0.00012
#
# Epoch 00016: val_loss did not improve from 0.00003
# 100/100 [==============================] - 0s 4ms/step - loss: 1.2736e-04 - val_loss: 1.6289e-04
# Epoch 17/1000
#  87/100 [=========================>....] - ETA: 0s - loss: 1.1826e-04
# Epoch 00017: loss improved from 0.00012 to 0.00012, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00017: val_loss did not improve from 0.00003
# 100/100 [==============================] - 0s 5ms/step - loss: 1.2233e-04 - val_loss: 5.9964e-05
# Epoch 18/1000
#  97/100 [============================>.] - ETA: 0s - loss: 1.1703e-04
# Epoch 00018: loss improved from 0.00012 to 0.00012, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00018: val_loss did not improve from 0.00003
# 100/100 [==============================] - 0s 5ms/step - loss: 1.1558e-04 - val_loss: 2.5443e-04
# Epoch 19/1000
#  83/100 [=======================>......] - ETA: 0s - loss: 1.2168e-04
# Epoch 00019: loss did not improve from 0.00012
#
# Epoch 00019: val_loss did not improve from 0.00003
# 100/100 [==============================] - 0s 5ms/step - loss: 1.2448e-04 - val_loss: 1.4329e-04
# Epoch 20/1000
#  83/100 [=======================>......] - ETA: 0s - loss: 1.2136e-04
# Epoch 00020: loss did not improve from 0.00012
#
# Epoch 00020: val_loss did not improve from 0.00003
# 100/100 [==============================] - 0s 4ms/step - loss: 1.1602e-04 - val_loss: 1.0919e-04
# Epoch 21/1000
#  87/100 [=========================>....] - ETA: 0s - loss: 1.2583e-04
# Epoch 00021: loss did not improve from 0.00012
#
# Epoch 00021: val_loss did not improve from 0.00003
# 100/100 [==============================] - 0s 4ms/step - loss: 1.2539e-04 - val_loss: 3.4556e-05
# Epoch 22/1000
#  86/100 [========================>.....] - ETA: 0s - loss: 1.1688e-04
# Epoch 00022: loss did not improve from 0.00012
#
# Epoch 00022: val_loss did not improve from 0.00003
# 100/100 [==============================] - 0s 4ms/step - loss: 1.1582e-04 - val_loss: 5.4257e-05
# Epoch 23/1000
#  86/100 [========================>.....] - ETA: 0s - loss: 1.1155e-04
# Epoch 00023: loss improved from 0.00012 to 0.00011, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00023: val_loss did not improve from 0.00003
# 100/100 [==============================] - 0s 5ms/step - loss: 1.0704e-04 - val_loss: 1.6892e-04
# Epoch 24/1000
#  84/100 [========================>.....] - ETA: 0s - loss: 1.1264e-04
# Epoch 00024: loss did not improve from 0.00011
#
# Epoch 00024: val_loss did not improve from 0.00003
# 100/100 [==============================] - 0s 5ms/step - loss: 1.1389e-04 - val_loss: 5.9577e-05
# Epoch 25/1000
#  86/100 [========================>.....] - ETA: 0s - loss: 1.1812e-04
# Epoch 00025: loss did not improve from 0.00011
#
# Epoch 00025: val_loss did not improve from 0.00003
# 100/100 [==============================] - 0s 4ms/step - loss: 1.2325e-04 - val_loss: 1.5878e-04
# Epoch 26/1000
#  97/100 [============================>.] - ETA: 0s - loss: 1.0491e-04
# Epoch 00026: loss improved from 0.00011 to 0.00010, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00026: val_loss did not improve from 0.00003
# 100/100 [==============================] - 1s 5ms/step - loss: 1.0218e-04 - val_loss: 4.7263e-05
# Epoch 27/1000
#  93/100 [==========================>...] - ETA: 0s - loss: 1.0442e-04
# Epoch 00027: loss did not improve from 0.00010
#
# Epoch 00027: val_loss improved from 0.00003 to 0.00002, saving model to lstm_model\model_bestValLoss
# 100/100 [==============================] - 1s 5ms/step - loss: 1.0242e-04 - val_loss: 2.2191e-05
# Epoch 28/1000
#  84/100 [========================>.....] - ETA: 0s - loss: 1.0964e-04
# Epoch 00028: loss did not improve from 0.00010
#
# Epoch 00028: val_loss did not improve from 0.00002
# 100/100 [==============================] - 0s 4ms/step - loss: 1.0300e-04 - val_loss: 1.9021e-04
# Epoch 29/1000
#  83/100 [=======================>......] - ETA: 0s - loss: 1.1045e-04
# Epoch 00029: loss did not improve from 0.00010
#
# Epoch 00029: val_loss did not improve from 0.00002
# 100/100 [==============================] - 0s 4ms/step - loss: 1.0889e-04 - val_loss: 4.0662e-05
# Epoch 30/1000
#  86/100 [========================>.....] - ETA: 0s - loss: 1.0131e-04
# Epoch 00030: loss improved from 0.00010 to 0.00010, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00030: val_loss did not improve from 0.00002
# 100/100 [==============================] - 0s 4ms/step - loss: 1.0119e-04 - val_loss: 3.0628e-05
# Epoch 31/1000
#  86/100 [========================>.....] - ETA: 0s - loss: 9.7523e-05
# Epoch 00031: loss improved from 0.00010 to 0.00009, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00031: val_loss did not improve from 0.00002
# 100/100 [==============================] - 0s 5ms/step - loss: 9.3107e-05 - val_loss: 1.3236e-04
# Epoch 32/1000
#  88/100 [=========================>....] - ETA: 0s - loss: 1.0312e-04
# Epoch 00032: loss did not improve from 0.00009
#
# Epoch 00032: val_loss improved from 0.00002 to 0.00002, saving model to lstm_model\model_bestValLoss
# 100/100 [==============================] - 0s 5ms/step - loss: 1.0613e-04 - val_loss: 2.2137e-05
# Epoch 33/1000
#  84/100 [========================>.....] - ETA: 0s - loss: 8.8234e-05
# Epoch 00033: loss improved from 0.00009 to 0.00009, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00033: val_loss did not improve from 0.00002
# 100/100 [==============================] - 0s 4ms/step - loss: 9.1312e-05 - val_loss: 3.7299e-05
# Epoch 34/1000
#  86/100 [========================>.....] - ETA: 0s - loss: 9.1406e-05
# Epoch 00034: loss did not improve from 0.00009
#
# Epoch 00034: val_loss did not improve from 0.00002
# 100/100 [==============================] - 0s 5ms/step - loss: 9.5248e-05 - val_loss: 7.8431e-05
# Epoch 35/1000
#  88/100 [=========================>....] - ETA: 0s - loss: 1.0272e-04
# Epoch 00035: loss did not improve from 0.00009
#
# Epoch 00035: val_loss did not improve from 0.00002
# 100/100 [==============================] - 0s 4ms/step - loss: 9.4525e-05 - val_loss: 3.8225e-05
# Epoch 36/1000
#  86/100 [========================>.....] - ETA: 0s - loss: 9.0968e-05
# Epoch 00036: loss improved from 0.00009 to 0.00009, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00036: val_loss did not improve from 0.00002
# 100/100 [==============================] - 0s 4ms/step - loss: 9.0737e-05 - val_loss: 3.7875e-05
# Epoch 37/1000
#  85/100 [========================>.....] - ETA: 0s - loss: 9.2114e-05
# Epoch 00037: loss did not improve from 0.00009
#
# Epoch 00037: val_loss did not improve from 0.00002
# 100/100 [==============================] - 0s 4ms/step - loss: 9.4562e-05 - val_loss: 6.2351e-05
# Epoch 38/1000
#  89/100 [=========================>....] - ETA: 0s - loss: 1.0728e-04
# Epoch 00038: loss did not improve from 0.00009
#
# Epoch 00038: val_loss did not improve from 0.00002
# 100/100 [==============================] - 0s 5ms/step - loss: 1.0156e-04 - val_loss: 1.4173e-04
# Epoch 39/1000
#  90/100 [==========================>...] - ETA: 0s - loss: 9.2477e-05
# Epoch 00039: loss did not improve from 0.00009
#
# Epoch 00039: val_loss did not improve from 0.00002
# 100/100 [==============================] - 0s 4ms/step - loss: 9.2111e-05 - val_loss: 1.1606e-04
# Epoch 40/1000
#  86/100 [========================>.....] - ETA: 0s - loss: 8.4967e-05
# Epoch 00040: loss improved from 0.00009 to 0.00008, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00040: val_loss did not improve from 0.00002
# 100/100 [==============================] - 0s 4ms/step - loss: 8.1236e-05 - val_loss: 7.1792e-05
# Epoch 41/1000
#  86/100 [========================>.....] - ETA: 0s - loss: 9.6529e-05
# Epoch 00041: loss did not improve from 0.00008
#
# Epoch 00041: val_loss did not improve from 0.00002
# 100/100 [==============================] - 0s 4ms/step - loss: 8.9263e-05 - val_loss: 7.9302e-05
# Epoch 42/1000
#  86/100 [========================>.....] - ETA: 0s - loss: 9.2431e-05
# Epoch 00042: loss did not improve from 0.00008
#
# Epoch 00042: val_loss did not improve from 0.00002
# 100/100 [==============================] - 0s 4ms/step - loss: 9.0799e-05 - val_loss: 1.4955e-04
# Epoch 43/1000
#  84/100 [========================>.....] - ETA: 0s - loss: 9.8088e-05
# Epoch 00043: loss did not improve from 0.00008
#
# Epoch 00043: val_loss did not improve from 0.00002
# 100/100 [==============================] - 0s 5ms/step - loss: 9.3317e-05 - val_loss: 9.4923e-05
# Epoch 44/1000
#  82/100 [=======================>......] - ETA: 0s - loss: 8.8338e-05
# Epoch 00044: loss did not improve from 0.00008
#
# Epoch 00044: val_loss did not improve from 0.00002
# 100/100 [==============================] - 0s 4ms/step - loss: 8.5148e-05 - val_loss: 5.2508e-05
# Epoch 45/1000
#  89/100 [=========================>....] - ETA: 0s - loss: 9.7409e-05
# Epoch 00045: loss did not improve from 0.00008
#
# Epoch 00045: val_loss did not improve from 0.00002
# 100/100 [==============================] - 0s 4ms/step - loss: 8.9783e-05 - val_loss: 4.7163e-05
# Epoch 46/1000
#  84/100 [========================>.....] - ETA: 0s - loss: 8.7726e-05
# Epoch 00046: loss did not improve from 0.00008
#
# Epoch 00046: val_loss did not improve from 0.00002
# 100/100 [==============================] - 0s 4ms/step - loss: 8.6009e-05 - val_loss: 1.1211e-04
# Epoch 47/1000
#  87/100 [=========================>....] - ETA: 0s - loss: 8.0627e-05
# Epoch 00047: loss improved from 0.00008 to 0.00008, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00047: val_loss did not improve from 0.00002
# 100/100 [==============================] - 0s 5ms/step - loss: 7.8513e-05 - val_loss: 9.2149e-05
# Epoch 48/1000
#  84/100 [========================>.....] - ETA: 0s - loss: 8.0062e-05
# Epoch 00048: loss did not improve from 0.00008
#
# Epoch 00048: val_loss improved from 0.00002 to 0.00001, saving model to lstm_model\model_bestValLoss
# 100/100 [==============================] - 0s 5ms/step - loss: 8.4382e-05 - val_loss: 1.1271e-05
# Epoch 49/1000
#  88/100 [=========================>....] - ETA: 0s - loss: 7.8626e-05
# Epoch 00049: loss did not improve from 0.00008
#
# Epoch 00049: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 4ms/step - loss: 8.0994e-05 - val_loss: 4.9606e-05
# Epoch 50/1000
#  88/100 [=========================>....] - ETA: 0s - loss: 8.2856e-05
# Epoch 00050: loss did not improve from 0.00008
#
# Epoch 00050: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 4ms/step - loss: 7.8585e-05 - val_loss: 2.0982e-05
# Epoch 51/1000
#  89/100 [=========================>....] - ETA: 0s - loss: 8.5660e-05
# Epoch 00051: loss did not improve from 0.00008
#
# Epoch 00051: val_loss did not improve from 0.00001
# 100/100 [==============================] - 1s 5ms/step - loss: 8.7367e-05 - val_loss: 4.8552e-05
# Epoch 52/1000
#  85/100 [========================>.....] - ETA: 0s - loss: 8.2283e-05
# Epoch 00052: loss did not improve from 0.00008
#
# Epoch 00052: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 5ms/step - loss: 8.0812e-05 - val_loss: 1.1020e-04
# Epoch 53/1000
#  83/100 [=======================>......] - ETA: 0s - loss: 7.5401e-05
# Epoch 00053: loss improved from 0.00008 to 0.00007, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00053: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 5ms/step - loss: 7.4874e-05 - val_loss: 4.2067e-05
# Epoch 54/1000
#  90/100 [==========================>...] - ETA: 0s - loss: 7.3636e-05
# Epoch 00054: loss did not improve from 0.00007
#
# Epoch 00054: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 4ms/step - loss: 8.0653e-05 - val_loss: 1.4214e-04
# Epoch 55/1000
#  89/100 [=========================>....] - ETA: 0s - loss: 7.3918e-05
# Epoch 00055: loss improved from 0.00007 to 0.00007, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00055: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 4ms/step - loss: 7.2128e-05 - val_loss: 5.4198e-05
# Epoch 56/1000
#  86/100 [========================>.....] - ETA: 0s - loss: 7.4476e-05
# Epoch 00056: loss did not improve from 0.00007
#
# Epoch 00056: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 4ms/step - loss: 7.5843e-05 - val_loss: 2.3165e-04
# Epoch 57/1000
#  84/100 [========================>.....] - ETA: 0s - loss: 7.4150e-05
# Epoch 00057: loss did not improve from 0.00007
#
# Epoch 00057: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 5ms/step - loss: 7.4412e-05 - val_loss: 6.7240e-05
# Epoch 58/1000
#  89/100 [=========================>....] - ETA: 0s - loss: 7.6051e-05
# Epoch 00058: loss did not improve from 0.00007
#
# Epoch 00058: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 4ms/step - loss: 8.3771e-05 - val_loss: 1.3481e-05
# Epoch 59/1000
#  87/100 [=========================>....] - ETA: 0s - loss: 6.7991e-05
# Epoch 00059: loss improved from 0.00007 to 0.00007, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00059: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 4ms/step - loss: 6.7712e-05 - val_loss: 7.3988e-05
# Epoch 60/1000
#  95/100 [===========================>..] - ETA: 0s - loss: 7.9322e-05
# Epoch 00060: loss did not improve from 0.00007
#
# Epoch 00060: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 5ms/step - loss: 7.8703e-05 - val_loss: 2.9343e-05
# Epoch 61/1000
#  88/100 [=========================>....] - ETA: 0s - loss: 7.7712e-05
# Epoch 00061: loss did not improve from 0.00007
#
# Epoch 00061: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 4ms/step - loss: 7.9275e-05 - val_loss: 2.5824e-05
# Epoch 62/1000
#  83/100 [=======================>......] - ETA: 0s - loss: 7.0149e-05
# Epoch 00062: loss did not improve from 0.00007
#
# Epoch 00062: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 5ms/step - loss: 7.0857e-05 - val_loss: 3.6747e-05
# Epoch 63/1000
#  87/100 [=========================>....] - ETA: 0s - loss: 7.1749e-05
# Epoch 00063: loss did not improve from 0.00007
#
# Epoch 00063: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 4ms/step - loss: 7.0037e-05 - val_loss: 4.9344e-05
# Epoch 64/1000
#  86/100 [========================>.....] - ETA: 0s - loss: 6.6958e-05
# Epoch 00064: loss did not improve from 0.00007
#
# Epoch 00064: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 4ms/step - loss: 7.0577e-05 - val_loss: 2.7775e-05
# Epoch 65/1000
#  87/100 [=========================>....] - ETA: 0s - loss: 7.1881e-05
# Epoch 00065: loss did not improve from 0.00007
#
# Epoch 00065: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 4ms/step - loss: 6.8866e-05 - val_loss: 2.0248e-05
# Epoch 66/1000
#  86/100 [========================>.....] - ETA: 0s - loss: 7.0980e-05
# Epoch 00066: loss did not improve from 0.00007
#
# Epoch 00066: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 4ms/step - loss: 7.2443e-05 - val_loss: 5.6343e-05
# Epoch 67/1000
#  96/100 [===========================>..] - ETA: 0s - loss: 6.9107e-05
# Epoch 00067: loss did not improve from 0.00007
#
# Epoch 00067: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 5ms/step - loss: 7.1512e-05 - val_loss: 2.8707e-04
# Epoch 68/1000
#  86/100 [========================>.....] - ETA: 0s - loss: 6.4590e-05
# Epoch 00068: loss improved from 0.00007 to 0.00007, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00068: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 4ms/step - loss: 6.6638e-05 - val_loss: 1.9755e-05
# Epoch 69/1000
#  85/100 [========================>.....] - ETA: 0s - loss: 6.7148e-05
# Epoch 00069: loss did not improve from 0.00007
#
# Epoch 00069: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 4ms/step - loss: 7.3420e-05 - val_loss: 4.1872e-05
# Epoch 70/1000
#  86/100 [========================>.....] - ETA: 0s - loss: 5.9827e-05
# Epoch 00070: loss improved from 0.00007 to 0.00006, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00070: val_loss improved from 0.00001 to 0.00001, saving model to lstm_model\model_bestValLoss
# 100/100 [==============================] - 0s 5ms/step - loss: 6.4878e-05 - val_loss: 1.0084e-05
# Epoch 71/1000
#  85/100 [========================>.....] - ETA: 0s - loss: 6.6621e-05
# Epoch 00071: loss improved from 0.00006 to 0.00006, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00071: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 5ms/step - loss: 6.0875e-05 - val_loss: 9.8324e-05
# Epoch 72/1000
#  98/100 [============================>.] - ETA: 0s - loss: 6.5611e-05
# Epoch 00072: loss did not improve from 0.00006
#
# Epoch 00072: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 5ms/step - loss: 6.6292e-05 - val_loss: 3.0199e-05
# Epoch 73/1000
#  85/100 [========================>.....] - ETA: 0s - loss: 6.9185e-05
# Epoch 00073: loss did not improve from 0.00006
#
# Epoch 00073: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 4ms/step - loss: 6.9815e-05 - val_loss: 1.3249e-05
# Epoch 74/1000
#  86/100 [========================>.....] - ETA: 0s - loss: 6.7632e-05
# Epoch 00074: loss did not improve from 0.00006
#
# Epoch 00074: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 4ms/step - loss: 6.2389e-05 - val_loss: 6.7138e-05
# Epoch 75/1000
#  90/100 [==========================>...] - ETA: 0s - loss: 6.8191e-05
# Epoch 00075: loss did not improve from 0.00006
#
# Epoch 00075: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 4ms/step - loss: 6.8267e-05 - val_loss: 9.7623e-05
# Epoch 76/1000
#  87/100 [=========================>....] - ETA: 0s - loss: 6.7741e-05
# Epoch 00076: loss did not improve from 0.00006
#
# Epoch 00076: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 5ms/step - loss: 6.3452e-05 - val_loss: 3.4061e-05
# Epoch 77/1000
#  85/100 [========================>.....] - ETA: 0s - loss: 6.9048e-05
# Epoch 00077: loss did not improve from 0.00006
#
# Epoch 00077: val_loss did not improve from 0.00001
# 100/100 [==============================] - 1s 5ms/step - loss: 6.4160e-05 - val_loss: 4.6850e-05
# Epoch 78/1000
#  90/100 [==========================>...] - ETA: 0s - loss: 6.4251e-05
# Epoch 00078: loss did not improve from 0.00006
#
# Epoch 00078: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 4ms/step - loss: 6.7232e-05 - val_loss: 6.5091e-05
# Epoch 79/1000
#  87/100 [=========================>....] - ETA: 0s - loss: 5.8737e-05
# Epoch 00079: loss did not improve from 0.00006
#
# Epoch 00079: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 4ms/step - loss: 6.1139e-05 - val_loss: 1.4922e-04
# Epoch 80/1000
#  87/100 [=========================>....] - ETA: 0s - loss: 6.2003e-05
# Epoch 00080: loss did not improve from 0.00006
#
# Epoch 00080: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 4ms/step - loss: 6.3756e-05 - val_loss: 6.3120e-05
# Epoch 81/1000
#  97/100 [============================>.] - ETA: 0s - loss: 6.2183e-05
# Epoch 00081: loss improved from 0.00006 to 0.00006, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00081: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 5ms/step - loss: 6.0696e-05 - val_loss: 1.3684e-05
# Epoch 82/1000
#  86/100 [========================>.....] - ETA: 0s - loss: 6.0651e-05
# Epoch 00082: loss did not improve from 0.00006
#
# Epoch 00082: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 4ms/step - loss: 6.3292e-05 - val_loss: 1.2410e-04
# Epoch 83/1000
#  88/100 [=========================>....] - ETA: 0s - loss: 5.7255e-05
# Epoch 00083: loss improved from 0.00006 to 0.00006, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00083: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 4ms/step - loss: 5.6633e-05 - val_loss: 1.2457e-04
# Epoch 84/1000
#  86/100 [========================>.....] - ETA: 0s - loss: 6.9784e-05
# Epoch 00084: loss did not improve from 0.00006
#
# Epoch 00084: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 4ms/step - loss: 6.4917e-05 - val_loss: 9.7516e-05
# Epoch 85/1000
#  83/100 [=======================>......] - ETA: 0s - loss: 6.2744e-05
# Epoch 00085: loss did not improve from 0.00006
#
# Epoch 00085: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 4ms/step - loss: 6.6329e-05 - val_loss: 4.2193e-05
# Epoch 86/1000
#  94/100 [===========================>..] - ETA: 0s - loss: 5.8212e-05
# Epoch 00086: loss did not improve from 0.00006
#
# Epoch 00086: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 5ms/step - loss: 5.6791e-05 - val_loss: 2.4682e-05
# Epoch 87/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 5.5695e-05
# Epoch 00087: loss improved from 0.00006 to 0.00006, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00087: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 4ms/step - loss: 5.6625e-05 - val_loss: 1.0358e-04
# Epoch 88/1000
#  85/100 [========================>.....] - ETA: 0s - loss: 6.5700e-05
# Epoch 00088: loss did not improve from 0.00006
#
# Epoch 00088: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 4ms/step - loss: 6.3381e-05 - val_loss: 8.7189e-05
# Epoch 89/1000
#  94/100 [===========================>..] - ETA: 0s - loss: 5.6329e-05
# Epoch 00089: loss did not improve from 0.00006
#
# Epoch 00089: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 4ms/step - loss: 5.7684e-05 - val_loss: 1.3383e-04
# Epoch 90/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 5.6247e-05
# Epoch 00090: loss did not improve from 0.00006
#
# Epoch 00090: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 4ms/step - loss: 6.2353e-05 - val_loss: 1.9922e-05
# Epoch 91/1000
#  95/100 [===========================>..] - ETA: 0s - loss: 5.4661e-05
# Epoch 00091: loss improved from 0.00006 to 0.00005, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00091: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 5ms/step - loss: 5.3609e-05 - val_loss: 2.2599e-05
# Epoch 92/1000
#  86/100 [========================>.....] - ETA: 0s - loss: 5.4817e-05
# Epoch 00092: loss did not improve from 0.00005
#
# Epoch 00092: val_loss improved from 0.00001 to 0.00001, saving model to lstm_model\model_bestValLoss
# 100/100 [==============================] - 0s 5ms/step - loss: 5.4558e-05 - val_loss: 9.7634e-06
# Epoch 93/1000
#  87/100 [=========================>....] - ETA: 0s - loss: 5.6870e-05
# Epoch 00093: loss did not improve from 0.00005
#
# Epoch 00093: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 4ms/step - loss: 5.9922e-05 - val_loss: 3.5113e-05
# Epoch 94/1000
#  84/100 [========================>.....] - ETA: 0s - loss: 5.9184e-05
# Epoch 00094: loss did not improve from 0.00005
#
# Epoch 00094: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 4ms/step - loss: 5.5774e-05 - val_loss: 8.9916e-05
# Epoch 95/1000
#  86/100 [========================>.....] - ETA: 0s - loss: 5.6712e-05
# Epoch 00095: loss did not improve from 0.00005
#
# Epoch 00095: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 5ms/step - loss: 5.8914e-05 - val_loss: 3.0064e-05
# Epoch 96/1000
#  98/100 [============================>.] - ETA: 0s - loss: 6.3341e-05
# Epoch 00096: loss did not improve from 0.00005
#
# Epoch 00096: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 4ms/step - loss: 6.4250e-05 - val_loss: 1.7539e-05
# Epoch 97/1000
#  90/100 [==========================>...] - ETA: 0s - loss: 5.9970e-05
# Epoch 00097: loss did not improve from 0.00005
#
# Epoch 00097: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 4ms/step - loss: 5.8050e-05 - val_loss: 1.0003e-04
# Epoch 98/1000
#  88/100 [=========================>....] - ETA: 0s - loss: 5.6928e-05
# Epoch 00098: loss did not improve from 0.00005
#
# Epoch 00098: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 4ms/step - loss: 5.5625e-05 - val_loss: 4.8422e-05
# Epoch 99/1000
#  87/100 [=========================>....] - ETA: 0s - loss: 5.5755e-05
# Epoch 00099: loss did not improve from 0.00005
#
# Epoch 00099: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 4ms/step - loss: 5.9176e-05 - val_loss: 4.8947e-05
# Epoch 100/1000
#  91/100 [==========================>...] - ETA: 0s - loss: 5.3111e-05
# Epoch 00100: loss improved from 0.00005 to 0.00005, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00100: val_loss improved from 0.00001 to 0.00001, saving model to lstm_model\model_bestValLoss
# 100/100 [==============================] - 0s 5ms/step - loss: 5.0504e-05 - val_loss: 8.4535e-06
# Epoch 101/1000
#  83/100 [=======================>......] - ETA: 0s - loss: 5.6206e-05
# Epoch 00101: loss did not improve from 0.00005
#
# Epoch 00101: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 5ms/step - loss: 5.3858e-05 - val_loss: 1.4430e-04
# Epoch 102/1000
#  95/100 [===========================>..] - ETA: 0s - loss: 5.7094e-05
# Epoch 00102: loss did not improve from 0.00005
#
# Epoch 00102: val_loss improved from 0.00001 to 0.00001, saving model to lstm_model\model_bestValLoss
# 100/100 [==============================] - 1s 5ms/step - loss: 5.4698e-05 - val_loss: 6.1394e-06
# Epoch 103/1000
#  87/100 [=========================>....] - ETA: 0s - loss: 5.2895e-05
# Epoch 00103: loss improved from 0.00005 to 0.00005, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00103: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 4ms/step - loss: 5.0443e-05 - val_loss: 6.6391e-05
# Epoch 104/1000
#  87/100 [=========================>....] - ETA: 0s - loss: 5.3683e-05
# Epoch 00104: loss did not improve from 0.00005
#
# Epoch 00104: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 4ms/step - loss: 5.4591e-05 - val_loss: 3.0636e-05
# Epoch 105/1000
#  98/100 [============================>.] - ETA: 0s - loss: 5.2479e-05
# Epoch 00105: loss did not improve from 0.00005
#
# Epoch 00105: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 5ms/step - loss: 5.1761e-05 - val_loss: 1.8981e-05
# Epoch 106/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 5.4299e-05
# Epoch 00106: loss did not improve from 0.00005
#
# Epoch 00106: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 4ms/step - loss: 5.1869e-05 - val_loss: 9.7620e-06
# Epoch 107/1000
#  86/100 [========================>.....] - ETA: 0s - loss: 5.2676e-05
# Epoch 00107: loss did not improve from 0.00005
#
# Epoch 00107: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 4ms/step - loss: 5.4510e-05 - val_loss: 2.1318e-05
# Epoch 108/1000
#  84/100 [========================>.....] - ETA: 0s - loss: 5.0465e-05
# Epoch 00108: loss did not improve from 0.00005
#
# Epoch 00108: val_loss did not improve from 0.00001
# 100/100 [==============================] - 0s 4ms/step - loss: 5.3348e-05 - val_loss: 3.9812e-05
# Epoch 109/1000
#  88/100 [=========================>....] - ETA: 0s - loss: 4.5748e-05
# Epoch 00109: loss improved from 0.00005 to 0.00005, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00109: val_loss improved from 0.00001 to 0.00000, saving model to lstm_model\model_bestValLoss
# 100/100 [==============================] - 0s 5ms/step - loss: 4.8602e-05 - val_loss: 4.2346e-06
# Epoch 110/1000
#  96/100 [===========================>..] - ETA: 0s - loss: 5.5735e-05
# Epoch 00110: loss did not improve from 0.00005
#
# Epoch 00110: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 5ms/step - loss: 5.4990e-05 - val_loss: 4.2251e-05
# Epoch 111/1000
#  85/100 [========================>.....] - ETA: 0s - loss: 4.5183e-05
# Epoch 00111: loss improved from 0.00005 to 0.00005, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00111: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 4.7754e-05 - val_loss: 4.7732e-05
# Epoch 112/1000
#  86/100 [========================>.....] - ETA: 0s - loss: 5.4158e-05
# Epoch 00112: loss did not improve from 0.00005
#
# Epoch 00112: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 5.0169e-05 - val_loss: 1.7061e-05
# Epoch 113/1000
#  87/100 [=========================>....] - ETA: 0s - loss: 5.1726e-05
# Epoch 00113: loss did not improve from 0.00005
#
# Epoch 00113: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 5.3125e-05 - val_loss: 5.2973e-05
# Epoch 114/1000
#  84/100 [========================>.....] - ETA: 0s - loss: 5.1980e-05
# Epoch 00114: loss did not improve from 0.00005
#
# Epoch 00114: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 5.3146e-05 - val_loss: 4.4036e-05
# Epoch 115/1000
#  83/100 [=======================>......] - ETA: 0s - loss: 4.7241e-05
# Epoch 00115: loss did not improve from 0.00005
#
# Epoch 00115: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 4.9264e-05 - val_loss: 4.7053e-05
# Epoch 116/1000
#  90/100 [==========================>...] - ETA: 0s - loss: 5.3213e-05
# Epoch 00116: loss did not improve from 0.00005
#
# Epoch 00116: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 4.9991e-05 - val_loss: 3.6997e-05
# Epoch 117/1000
#  90/100 [==========================>...] - ETA: 0s - loss: 5.5425e-05
# Epoch 00117: loss did not improve from 0.00005
#
# Epoch 00117: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 5.1201e-05 - val_loss: 1.5164e-04
# Epoch 118/1000
#  88/100 [=========================>....] - ETA: 0s - loss: 4.8088e-05
# Epoch 00118: loss did not improve from 0.00005
#
# Epoch 00118: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 4.8142e-05 - val_loss: 1.3084e-05
# Epoch 119/1000
#  85/100 [========================>.....] - ETA: 0s - loss: 5.2155e-05
# Epoch 00119: loss did not improve from 0.00005
#
# Epoch 00119: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 5ms/step - loss: 4.8025e-05 - val_loss: 4.6693e-05
# Epoch 120/1000
#  84/100 [========================>.....] - ETA: 0s - loss: 5.5718e-05
# Epoch 00120: loss did not improve from 0.00005
#
# Epoch 00120: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 5.5418e-05 - val_loss: 2.5799e-04
# Epoch 121/1000
#  87/100 [=========================>....] - ETA: 0s - loss: 4.6609e-05
# Epoch 00121: loss improved from 0.00005 to 0.00005, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00121: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 4.5082e-05 - val_loss: 4.3725e-05
# Epoch 122/1000
#  85/100 [========================>.....] - ETA: 0s - loss: 5.0430e-05
# Epoch 00122: loss did not improve from 0.00005
#
# Epoch 00122: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 4.8150e-05 - val_loss: 1.7172e-04
# Epoch 123/1000
#  86/100 [========================>.....] - ETA: 0s - loss: 5.0707e-05
# Epoch 00123: loss did not improve from 0.00005
#
# Epoch 00123: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 4.9361e-05 - val_loss: 9.5247e-05
# Epoch 124/1000
#  89/100 [=========================>....] - ETA: 0s - loss: 4.7168e-05
# Epoch 00124: loss did not improve from 0.00005
#
# Epoch 00124: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 5ms/step - loss: 4.8355e-05 - val_loss: 9.0632e-06
# Epoch 125/1000
#  84/100 [========================>.....] - ETA: 0s - loss: 4.6079e-05
# Epoch 00125: loss improved from 0.00005 to 0.00004, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00125: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 5ms/step - loss: 4.3672e-05 - val_loss: 3.4739e-05
# Epoch 126/1000
#  88/100 [=========================>....] - ETA: 0s - loss: 5.0782e-05
# Epoch 00126: loss did not improve from 0.00004
#
# Epoch 00126: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 4.8588e-05 - val_loss: 3.9800e-05
# Epoch 127/1000
#  88/100 [=========================>....] - ETA: 0s - loss: 5.3486e-05
# Epoch 00127: loss did not improve from 0.00004
#
# Epoch 00127: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 4.9037e-05 - val_loss: 4.4859e-05
# Epoch 128/1000
#  91/100 [==========================>...] - ETA: 0s - loss: 4.5470e-05
# Epoch 00128: loss did not improve from 0.00004
#
# Epoch 00128: val_loss did not improve from 0.00000
# 100/100 [==============================] - 1s 5ms/step - loss: 4.5605e-05 - val_loss: 1.8380e-05
# Epoch 129/1000
#  85/100 [========================>.....] - ETA: 0s - loss: 5.1551e-05
# Epoch 00129: loss did not improve from 0.00004
#
# Epoch 00129: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 4.8700e-05 - val_loss: 7.3904e-05
# Epoch 130/1000
#  87/100 [=========================>....] - ETA: 0s - loss: 4.7644e-05
# Epoch 00130: loss did not improve from 0.00004
#
# Epoch 00130: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 5.0748e-05 - val_loss: 1.2812e-05
# Epoch 131/1000
#  90/100 [==========================>...] - ETA: 0s - loss: 4.6653e-05
# Epoch 00131: loss did not improve from 0.00004
#
# Epoch 00131: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 4.5364e-05 - val_loss: 5.3084e-05
# Epoch 132/1000
#  88/100 [=========================>....] - ETA: 0s - loss: 4.7268e-05
# Epoch 00132: loss did not improve from 0.00004
#
# Epoch 00132: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 4.5595e-05 - val_loss: 1.1105e-05
# Epoch 133/1000
#  84/100 [========================>.....] - ETA: 0s - loss: 4.5682e-05
# Epoch 00133: loss did not improve from 0.00004
#
# Epoch 00133: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 4.4303e-05 - val_loss: 4.9110e-05
# Epoch 134/1000
#  84/100 [========================>.....] - ETA: 0s - loss: 4.4855e-05
# Epoch 00134: loss did not improve from 0.00004
#
# Epoch 00134: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 4.5207e-05 - val_loss: 8.2654e-06
# Epoch 135/1000
#  90/100 [==========================>...] - ETA: 0s - loss: 4.3813e-05
# Epoch 00135: loss did not improve from 0.00004
#
# Epoch 00135: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 4.6077e-05 - val_loss: 8.5038e-05
# Epoch 136/1000
#  89/100 [=========================>....] - ETA: 0s - loss: 4.2139e-05
# Epoch 00136: loss improved from 0.00004 to 0.00004, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00136: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 4.0169e-05 - val_loss: 1.2539e-04
# Epoch 137/1000
#  86/100 [========================>.....] - ETA: 0s - loss: 4.3349e-05
# Epoch 00137: loss did not improve from 0.00004
#
# Epoch 00137: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 4.5275e-05 - val_loss: 4.4709e-06
# Epoch 138/1000
#  88/100 [=========================>....] - ETA: 0s - loss: 4.4351e-05
# Epoch 00138: loss did not improve from 0.00004
#
# Epoch 00138: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 4.5469e-05 - val_loss: 8.9920e-06
# Epoch 139/1000
#  96/100 [===========================>..] - ETA: 0s - loss: 4.2157e-05
# Epoch 00139: loss did not improve from 0.00004
#
# Epoch 00139: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 5ms/step - loss: 4.2230e-05 - val_loss: 1.5846e-05
# Epoch 140/1000
#  82/100 [=======================>......] - ETA: 0s - loss: 4.3121e-05
# Epoch 00140: loss did not improve from 0.00004
#
# Epoch 00140: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 4.3481e-05 - val_loss: 5.1522e-06
# Epoch 141/1000
#  90/100 [==========================>...] - ETA: 0s - loss: 4.3616e-05
# Epoch 00141: loss did not improve from 0.00004
#
# Epoch 00141: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 4.3755e-05 - val_loss: 1.3085e-05
# Epoch 142/1000
#  82/100 [=======================>......] - ETA: 0s - loss: 4.0822e-05
# Epoch 00142: loss did not improve from 0.00004
#
# Epoch 00142: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 4.2240e-05 - val_loss: 2.6683e-05
# Epoch 143/1000
#  85/100 [========================>.....] - ETA: 0s - loss: 4.5773e-05
# Epoch 00143: loss did not improve from 0.00004
#
# Epoch 00143: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 4.2485e-05 - val_loss: 1.7487e-05
# Epoch 144/1000
#  82/100 [=======================>......] - ETA: 0s - loss: 4.3390e-05
# Epoch 00144: loss did not improve from 0.00004
#
# Epoch 00144: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 4.4577e-05 - val_loss: 7.9997e-06
# Epoch 145/1000
#  88/100 [=========================>....] - ETA: 0s - loss: 4.2669e-05
# Epoch 00145: loss did not improve from 0.00004
#
# Epoch 00145: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 4.3431e-05 - val_loss: 8.9846e-06
# Epoch 146/1000
#  87/100 [=========================>....] - ETA: 0s - loss: 4.1729e-05
# Epoch 00146: loss did not improve from 0.00004
#
# Epoch 00146: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 4.3562e-05 - val_loss: 6.6416e-06
# Epoch 147/1000
#  88/100 [=========================>....] - ETA: 0s - loss: 4.1291e-05
# Epoch 00147: loss improved from 0.00004 to 0.00004, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00147: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 5ms/step - loss: 4.0063e-05 - val_loss: 1.3878e-05
# Epoch 148/1000
#  99/100 [============================>.] - ETA: 0s - loss: 4.1966e-05
# Epoch 00148: loss did not improve from 0.00004
#
# Epoch 00148: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 4.2560e-05 - val_loss: 4.6331e-05
# Epoch 149/1000
#  86/100 [========================>.....] - ETA: 0s - loss: 4.1545e-05
# Epoch 00149: loss did not improve from 0.00004
#
# Epoch 00149: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 5ms/step - loss: 4.1078e-05 - val_loss: 6.5636e-05
# Epoch 150/1000
#  86/100 [========================>.....] - ETA: 0s - loss: 3.8519e-05
# Epoch 00150: loss did not improve from 0.00004
#
# Epoch 00150: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 4.2867e-05 - val_loss: 1.0755e-04
# Epoch 151/1000
#  87/100 [=========================>....] - ETA: 0s - loss: 4.3300e-05
# Epoch 00151: loss did not improve from 0.00004
#
# Epoch 00151: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 4.1876e-05 - val_loss: 3.0392e-05
# Epoch 152/1000
#  88/100 [=========================>....] - ETA: 0s - loss: 4.2633e-05
# Epoch 00152: loss did not improve from 0.00004
#
# Epoch 00152: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 4.2118e-05 - val_loss: 3.5742e-05
# Epoch 153/1000
#  83/100 [=======================>......] - ETA: 0s - loss: 4.3313e-05
# Epoch 00153: loss did not improve from 0.00004
#
# Epoch 00153: val_loss improved from 0.00000 to 0.00000, saving model to lstm_model\model_bestValLoss
# 100/100 [==============================] - 1s 6ms/step - loss: 4.5223e-05 - val_loss: 2.6740e-06
# Epoch 154/1000
#  84/100 [========================>.....] - ETA: 0s - loss: 4.0667e-05
# Epoch 00154: loss did not improve from 0.00004
#
# Epoch 00154: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 4.1715e-05 - val_loss: 1.9561e-05
# Epoch 155/1000
#  87/100 [=========================>....] - ETA: 0s - loss: 4.0859e-05
# Epoch 00155: loss did not improve from 0.00004
#
# Epoch 00155: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 4.0710e-05 - val_loss: 7.3598e-06
# Epoch 156/1000
#  90/100 [==========================>...] - ETA: 0s - loss: 4.0508e-05
# Epoch 00156: loss did not improve from 0.00004
#
# Epoch 00156: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 4.0624e-05 - val_loss: 2.4131e-05
# Epoch 157/1000
#  88/100 [=========================>....] - ETA: 0s - loss: 3.9552e-05
# Epoch 00157: loss improved from 0.00004 to 0.00004, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00157: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 3.9588e-05 - val_loss: 5.1893e-05
# Epoch 158/1000
#  85/100 [========================>.....] - ETA: 0s - loss: 3.8985e-05
# Epoch 00158: loss improved from 0.00004 to 0.00004, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00158: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 5ms/step - loss: 3.8581e-05 - val_loss: 3.1044e-05
# Epoch 159/1000
#  90/100 [==========================>...] - ETA: 0s - loss: 4.0751e-05
# Epoch 00159: loss did not improve from 0.00004
#
# Epoch 00159: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 4.2230e-05 - val_loss: 5.0688e-06
# Epoch 160/1000
#  89/100 [=========================>....] - ETA: 0s - loss: 3.7175e-05
# Epoch 00160: loss improved from 0.00004 to 0.00004, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00160: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 3.6670e-05 - val_loss: 4.3199e-05
# Epoch 161/1000
#  89/100 [=========================>....] - ETA: 0s - loss: 3.9993e-05
# Epoch 00161: loss did not improve from 0.00004
#
# Epoch 00161: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 4.2754e-05 - val_loss: 1.3217e-05
# Epoch 162/1000
#  89/100 [=========================>....] - ETA: 0s - loss: 4.2591e-05
# Epoch 00162: loss did not improve from 0.00004
#
# Epoch 00162: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 5ms/step - loss: 4.0106e-05 - val_loss: 1.5084e-05
# Epoch 163/1000
#  84/100 [========================>.....] - ETA: 0s - loss: 4.2982e-05
# Epoch 00163: loss did not improve from 0.00004
#
# Epoch 00163: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 4.2284e-05 - val_loss: 1.1297e-05
# Epoch 164/1000
#  87/100 [=========================>....] - ETA: 0s - loss: 4.1497e-05
# Epoch 00164: loss did not improve from 0.00004
#
# Epoch 00164: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 3.8254e-05 - val_loss: 3.4087e-05
# Epoch 165/1000
#  88/100 [=========================>....] - ETA: 0s - loss: 3.8969e-05
# Epoch 00165: loss improved from 0.00004 to 0.00004, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00165: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 3.6641e-05 - val_loss: 9.3168e-05
# Epoch 166/1000
#  88/100 [=========================>....] - ETA: 0s - loss: 4.4140e-05
# Epoch 00166: loss did not improve from 0.00004
#
# Epoch 00166: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 4.3005e-05 - val_loss: 5.5559e-06
# Epoch 167/1000
#  86/100 [========================>.....] - ETA: 0s - loss: 3.9991e-05
# Epoch 00167: loss did not improve from 0.00004
#
# Epoch 00167: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 4.3123e-05 - val_loss: 6.6420e-05
# Epoch 168/1000
#  98/100 [============================>.] - ETA: 0s - loss: 3.5646e-05
# Epoch 00168: loss improved from 0.00004 to 0.00004, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00168: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 5ms/step - loss: 3.5196e-05 - val_loss: 2.4456e-05
# Epoch 169/1000
#  89/100 [=========================>....] - ETA: 0s - loss: 3.7014e-05
# Epoch 00169: loss did not improve from 0.00004
#
# Epoch 00169: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 3.7462e-05 - val_loss: 3.3789e-05
# Epoch 170/1000
#  85/100 [========================>.....] - ETA: 0s - loss: 3.7314e-05
# Epoch 00170: loss did not improve from 0.00004
#
# Epoch 00170: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 3.8620e-05 - val_loss: 2.7028e-05
# Epoch 171/1000
#  91/100 [==========================>...] - ETA: 0s - loss: 3.6132e-05
# Epoch 00171: loss did not improve from 0.00004
#
# Epoch 00171: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 3.6771e-05 - val_loss: 4.0373e-06
# Epoch 172/1000
#  85/100 [========================>.....] - ETA: 0s - loss: 3.9128e-05
# Epoch 00172: loss did not improve from 0.00004
#
# Epoch 00172: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 5ms/step - loss: 4.0614e-05 - val_loss: 1.5450e-05
# Epoch 173/1000
#  84/100 [========================>.....] - ETA: 0s - loss: 3.5655e-05
# Epoch 00173: loss improved from 0.00004 to 0.00003, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00173: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 5ms/step - loss: 3.4936e-05 - val_loss: 5.5268e-06
# Epoch 174/1000
#  86/100 [========================>.....] - ETA: 0s - loss: 3.9216e-05
# Epoch 00174: loss did not improve from 0.00003
#
# Epoch 00174: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 3.9638e-05 - val_loss: 1.4157e-04
# Epoch 175/1000
#  86/100 [========================>.....] - ETA: 0s - loss: 3.5320e-05
# Epoch 00175: loss did not improve from 0.00003
#
# Epoch 00175: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 3.8363e-05 - val_loss: 4.9910e-05
# Epoch 176/1000
#  85/100 [========================>.....] - ETA: 0s - loss: 3.5707e-05
# Epoch 00176: loss did not improve from 0.00003
#
# Epoch 00176: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 3.5787e-05 - val_loss: 3.6125e-05
# Epoch 177/1000
#  95/100 [===========================>..] - ETA: 0s - loss: 3.7673e-05
# Epoch 00177: loss did not improve from 0.00003
#
# Epoch 00177: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 5ms/step - loss: 3.8970e-05 - val_loss: 1.6946e-05
# Epoch 178/1000
#  99/100 [============================>.] - ETA: 0s - loss: 3.6802e-05
# Epoch 00178: loss did not improve from 0.00003
#
# Epoch 00178: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 3.6540e-05 - val_loss: 9.9151e-06
# Epoch 179/1000
#  95/100 [===========================>..] - ETA: 0s - loss: 3.6384e-05
# Epoch 00179: loss did not improve from 0.00003
#
# Epoch 00179: val_loss did not improve from 0.00000
# 100/100 [==============================] - 1s 5ms/step - loss: 3.7515e-05 - val_loss: 3.9707e-05
# Epoch 180/1000
#  88/100 [=========================>....] - ETA: 0s - loss: 3.4471e-05
# Epoch 00180: loss improved from 0.00003 to 0.00003, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00180: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 3.4178e-05 - val_loss: 2.4603e-05
# Epoch 181/1000
#  87/100 [=========================>....] - ETA: 0s - loss: 4.1325e-05
# Epoch 00181: loss did not improve from 0.00003
#
# Epoch 00181: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 3.8794e-05 - val_loss: 9.9263e-06
# Epoch 182/1000
#  97/100 [============================>.] - ETA: 0s - loss: 3.8655e-05
# Epoch 00182: loss did not improve from 0.00003
#
# Epoch 00182: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 5ms/step - loss: 3.7564e-05 - val_loss: 5.2802e-06
# Epoch 183/1000
#  89/100 [=========================>....] - ETA: 0s - loss: 3.8485e-05
# Epoch 00183: loss did not improve from 0.00003
#
# Epoch 00183: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 3.7990e-05 - val_loss: 1.1727e-05
# Epoch 184/1000
#  83/100 [=======================>......] - ETA: 0s - loss: 3.5736e-05
# Epoch 00184: loss did not improve from 0.00003
#
# Epoch 00184: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 3.4497e-05 - val_loss: 5.6672e-05
# Epoch 185/1000
#  89/100 [=========================>....] - ETA: 0s - loss: 3.4778e-05
# Epoch 00185: loss did not improve from 0.00003
#
# Epoch 00185: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 3.7154e-05 - val_loss: 3.7930e-05
# Epoch 186/1000
#  90/100 [==========================>...] - ETA: 0s - loss: 3.7000e-05
# Epoch 00186: loss did not improve from 0.00003
#
# Epoch 00186: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 3.7753e-05 - val_loss: 2.3389e-05
# Epoch 187/1000
#  84/100 [========================>.....] - ETA: 0s - loss: 3.7219e-05
# Epoch 00187: loss did not improve from 0.00003
#
# Epoch 00187: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 3.6228e-05 - val_loss: 4.9601e-05
# Epoch 188/1000
#  87/100 [=========================>....] - ETA: 0s - loss: 3.5205e-05
# Epoch 00188: loss did not improve from 0.00003
#
# Epoch 00188: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 3.5193e-05 - val_loss: 2.7241e-05
# Epoch 189/1000
#  86/100 [========================>.....] - ETA: 0s - loss: 3.5772e-05
# Epoch 00189: loss improved from 0.00003 to 0.00003, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00189: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 5ms/step - loss: 3.3907e-05 - val_loss: 2.8306e-05
# Epoch 190/1000
#  84/100 [========================>.....] - ETA: 0s - loss: 3.4674e-05
# Epoch 00190: loss did not improve from 0.00003
#
# Epoch 00190: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 3.5651e-05 - val_loss: 8.6255e-05
# Epoch 191/1000
#  86/100 [========================>.....] - ETA: 0s - loss: 3.8062e-05
# Epoch 00191: loss did not improve from 0.00003
#
# Epoch 00191: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 3.4741e-05 - val_loss: 9.8974e-05
# Epoch 192/1000
#  99/100 [============================>.] - ETA: 0s - loss: 3.5065e-05
# Epoch 00192: loss did not improve from 0.00003
#
# Epoch 00192: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 3.4927e-05 - val_loss: 5.7794e-05
# Epoch 193/1000
#  91/100 [==========================>...] - ETA: 0s - loss: 3.5260e-05
# Epoch 00193: loss did not improve from 0.00003
#
# Epoch 00193: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 3.7192e-05 - val_loss: 2.1259e-05
# Epoch 194/1000
#  86/100 [========================>.....] - ETA: 0s - loss: 3.0666e-05
# Epoch 00194: loss improved from 0.00003 to 0.00003, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00194: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 3.2048e-05 - val_loss: 4.4185e-06
# Epoch 195/1000
#  99/100 [============================>.] - ETA: 0s - loss: 3.2427e-05
# Epoch 00195: loss did not improve from 0.00003
#
# Epoch 00195: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 3.2511e-05 - val_loss: 3.2249e-05
# Epoch 196/1000
#  84/100 [========================>.....] - ETA: 0s - loss: 3.6135e-05
# Epoch 00196: loss did not improve from 0.00003
#
# Epoch 00196: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 3.4334e-05 - val_loss: 2.7979e-05
# Epoch 197/1000
#  83/100 [=======================>......] - ETA: 0s - loss: 3.4913e-05
# Epoch 00197: loss did not improve from 0.00003
#
# Epoch 00197: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 3.5611e-05 - val_loss: 6.0149e-06
# Epoch 198/1000
#  84/100 [========================>.....] - ETA: 0s - loss: 3.8928e-05
# Epoch 00198: loss did not improve from 0.00003
#
# Epoch 00198: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 3.6245e-05 - val_loss: 1.6174e-05
# Epoch 199/1000
#  87/100 [=========================>....] - ETA: 0s - loss: 3.3753e-05
# Epoch 00199: loss did not improve from 0.00003
#
# Epoch 00199: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 3.3834e-05 - val_loss: 2.2975e-05
# Epoch 200/1000
#  86/100 [========================>.....] - ETA: 0s - loss: 3.5205e-05
# Epoch 00200: loss did not improve from 0.00003
#
# Epoch 00200: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 5ms/step - loss: 3.6437e-05 - val_loss: 3.9357e-05
# Epoch 201/1000
#  84/100 [========================>.....] - ETA: 0s - loss: 3.3271e-05
# Epoch 00201: loss improved from 0.00003 to 0.00003, saving model to lstm_model\model_bestTrainLoss
#
# Epoch 00201: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 5ms/step - loss: 3.1826e-05 - val_loss: 3.2677e-05
# Epoch 202/1000
#  85/100 [========================>.....] - ETA: 0s - loss: 3.4045e-05
# Epoch 00202: loss did not improve from 0.00003
#
# Epoch 00202: val_loss did not improve from 0.00000
# 100/100 [==============================] - 0s 4ms/step - loss: 3.5486e-05 - val_loss: 1.4559e-05
# Epoch 203/1000
#  90/100 [==========================>...] - ETA: 0s - loss: 3.2748e-05
# Epoch 00203: loss did not improve from 0.00003
#
# Epoch 00203: val_loss did not improve from 0.00000
# Restoring model weights from the end of the best epoch.
# 100/100 [==============================] - 0s 5ms/step - loss: 3.4318e-05 - val_loss: 3.2410e-05
# Epoch 00203: early stopping

# %% [markdown]
# ## Transformer

# %%
modelpath="new_transf_lr01"
if not os.path.exists(modelpath):
    os.makedirs(modelpath)
max_epochs=1000
steps_per_epoch = 100
validation_steps = 100
validation_freq = 1
lr=0.01

es_callback = tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, restore_best_weights=True, verbose=True)
# mc_trainLoss_callback = tf.keras.callbacks.ModelCheckpoint(filepath="%s.bestTrainLoss" % modelpath, monitor='loss', verbose=1, save_best_only=True, mode=min)
mc_valLoss_callback = tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(modelpath, "model_bestValLoss"), monitor='val_loss', verbose=1, save_best_only=True, mode=min)
# tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir = ".\model_logs_tb", histogram_freq=1)

# Build the Transformer model
# model = build_transformer_model(mean_in, std_in, mean_out, std_out, input_shape=input_shape)
model = TimeSeriesTransformer(num_layers=2, d_model=64, num_heads=4, dff=128, 
                              input_shape=input_shape, output_dim=len(mean_out), rate=lr)
model.compile(optimizer="adam", loss="mse")

history = model.fit(train_data, epochs=max_epochs, steps_per_epoch=steps_per_epoch,
                        validation_data=val_data, validation_steps=validation_steps, validation_freq=validation_freq,
                        callbacks=[mc_valLoss_callback ,es_callback])
model.save(os.path.join(modelpath, 'transformer_model'), save_format='tf')
# Out:
# WARNING:tensorflow:ModelCheckpoint mode <built-in function min> is unknown, fallback to auto mode.
# Train on 100 steps, validate on 100 steps
# Epoch 1/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 0.1014
# Epoch 00001: val_loss improved from inf to 0.00480, saving model to new_transf_lr01\model_bestValLoss
# 100/100 [==============================] - 2s 20ms/step - loss: 0.0946 - val_loss: 0.0048
# Epoch 2/1000
#  93/100 [==========================>...] - ETA: 0s - loss: 0.0148
# Epoch 00002: val_loss improved from 0.00480 to 0.00252, saving model to new_transf_lr01\model_bestValLoss
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0147 - val_loss: 0.0025
# Epoch 3/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 0.0116
# Epoch 00003: val_loss did not improve from 0.00252
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0116 - val_loss: 0.0033
# Epoch 4/1000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0094
# Epoch 00004: val_loss improved from 0.00252 to 0.00148, saving model to new_transf_lr01\model_bestValLoss
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0093 - val_loss: 0.0015
# Epoch 5/1000
#  93/100 [==========================>...] - ETA: 0s - loss: 0.0081
# Epoch 00005: val_loss improved from 0.00148 to 0.00090, saving model to new_transf_lr01\model_bestValLoss
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0079 - val_loss: 9.0015e-04
# Epoch 6/1000
#  94/100 [===========================>..] - ETA: 0s - loss: 0.0066
# Epoch 00006: val_loss did not improve from 0.00090
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0066 - val_loss: 0.0015
# Epoch 7/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 0.0061
# Epoch 00007: val_loss did not improve from 0.00090
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0061 - val_loss: 0.0012
# Epoch 8/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 0.0049
# Epoch 00008: val_loss did not improve from 0.00090
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0049 - val_loss: 0.0013
# Epoch 9/1000
#  95/100 [===========================>..] - ETA: 0s - loss: 0.0044
# Epoch 00009: val_loss did not improve from 0.00090
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0044 - val_loss: 0.0017
# Epoch 10/1000
#  97/100 [============================>.] - ETA: 0s - loss: 0.0040
# Epoch 00010: val_loss did not improve from 0.00090
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0040 - val_loss: 0.0015
# Epoch 11/1000
#  95/100 [===========================>..] - ETA: 0s - loss: 0.0035
# Epoch 00011: val_loss improved from 0.00090 to 0.00060, saving model to new_transf_lr01\model_bestValLoss
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0035 - val_loss: 5.9789e-04
# Epoch 12/1000
#  93/100 [==========================>...] - ETA: 0s - loss: 0.0028
# Epoch 00012: val_loss did not improve from 0.00060
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0029 - val_loss: 7.7186e-04
# Epoch 13/1000
#  93/100 [==========================>...] - ETA: 0s - loss: 0.0030
# Epoch 00013: val_loss did not improve from 0.00060
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0029 - val_loss: 6.9190e-04
# Epoch 14/1000
#  94/100 [===========================>..] - ETA: 0s - loss: 0.0025
# Epoch 00014: val_loss improved from 0.00060 to 0.00041, saving model to new_transf_lr01\model_bestValLoss
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0025 - val_loss: 4.1020e-04
# Epoch 15/1000
#  91/100 [==========================>...] - ETA: 0s - loss: 0.0026
# Epoch 00015: val_loss improved from 0.00041 to 0.00030, saving model to new_transf_lr01\model_bestValLoss
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0025 - val_loss: 2.9623e-04
# Epoch 16/1000
#  98/100 [============================>.] - ETA: 0s - loss: 0.0020
# Epoch 00016: val_loss did not improve from 0.00030
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0020 - val_loss: 4.8266e-04
# Epoch 17/1000
#  97/100 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 00017: val_loss improved from 0.00030 to 0.00019, saving model to new_transf_lr01\model_bestValLoss
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0018 - val_loss: 1.9237e-04
# Epoch 18/1000
#  98/100 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 00018: val_loss did not improve from 0.00019
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0019 - val_loss: 5.5166e-04
# Epoch 19/1000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 00019: val_loss did not improve from 0.00019
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0017 - val_loss: 6.6387e-04
# Epoch 20/1000
#  94/100 [===========================>..] - ETA: 0s - loss: 0.0017
# Epoch 00020: val_loss did not improve from 0.00019
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0017 - val_loss: 5.8520e-04
# Epoch 21/1000
#  94/100 [===========================>..] - ETA: 0s - loss: 0.0014
# Epoch 00021: val_loss did not improve from 0.00019
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0015 - val_loss: 7.5251e-04
# Epoch 22/1000
#  98/100 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 00022: val_loss did not improve from 0.00019
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 23/1000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 00023: val_loss improved from 0.00019 to 0.00015, saving model to new_transf_lr01\model_bestValLoss
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0014 - val_loss: 1.4791e-04
# Epoch 24/1000
#  91/100 [==========================>...] - ETA: 0s - loss: 0.0013
# Epoch 00024: val_loss did not improve from 0.00015
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0013 - val_loss: 2.7785e-04
# Epoch 25/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 0.0012
# Epoch 00025: val_loss did not improve from 0.00015
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0012 - val_loss: 3.9841e-04
# Epoch 26/1000
#  98/100 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 00026: val_loss did not improve from 0.00015
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0011 - val_loss: 3.6426e-04
# Epoch 27/1000
#  94/100 [===========================>..] - ETA: 0s - loss: 0.0010
# Epoch 00027: val_loss did not improve from 0.00015
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0010 - val_loss: 2.6054e-04
# Epoch 28/1000
#  94/100 [===========================>..] - ETA: 0s - loss: 0.0011
# Epoch 00028: val_loss did not improve from 0.00015
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0011 - val_loss: 7.0215e-04
# Epoch 29/1000
#  93/100 [==========================>...] - ETA: 0s - loss: 0.0012
# Epoch 00029: val_loss did not improve from 0.00015
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0012 - val_loss: 3.6456e-04
# Epoch 30/1000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 00030: val_loss did not improve from 0.00015
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0012 - val_loss: 2.8945e-04
# Epoch 31/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 0.0012
# Epoch 00031: val_loss did not improve from 0.00015
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0012 - val_loss: 5.4798e-04
# Epoch 32/1000
#  95/100 [===========================>..] - ETA: 0s - loss: 0.0010
# Epoch 00032: val_loss did not improve from 0.00015
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0010 - val_loss: 4.8344e-04
# Epoch 33/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 9.9445e-04
# Epoch 00033: val_loss did not improve from 0.00015
# 100/100 [==============================] - 1s 9ms/step - loss: 9.8897e-04 - val_loss: 4.1179e-04
# Epoch 34/1000
#  93/100 [==========================>...] - ETA: 0s - loss: 0.0010
# Epoch 00034: val_loss did not improve from 0.00015
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0011 - val_loss: 3.0986e-04
# Epoch 35/1000
#  94/100 [===========================>..] - ETA: 0s - loss: 8.6434e-04
# Epoch 00035: val_loss did not improve from 0.00015
# 100/100 [==============================] - 1s 8ms/step - loss: 8.7338e-04 - val_loss: 8.6518e-04
# Epoch 36/1000
#  91/100 [==========================>...] - ETA: 0s - loss: 9.8285e-04
# Epoch 00036: val_loss did not improve from 0.00015
# 100/100 [==============================] - 1s 8ms/step - loss: 9.7495e-04 - val_loss: 3.5064e-04
# Epoch 37/1000
#  94/100 [===========================>..] - ETA: 0s - loss: 9.9219e-04
# Epoch 00037: val_loss did not improve from 0.00015
# 100/100 [==============================] - 1s 8ms/step - loss: 9.9021e-04 - val_loss: 3.9466e-04
# Epoch 38/1000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 00038: val_loss did not improve from 0.00015
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0012 - val_loss: 5.7065e-04
# Epoch 39/1000
#  97/100 [============================>.] - ETA: 0s - loss: 9.5120e-04
# Epoch 00039: val_loss did not improve from 0.00015
# 100/100 [==============================] - 1s 8ms/step - loss: 9.4338e-04 - val_loss: 4.0101e-04
# Epoch 40/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 8.0779e-04
# Epoch 00040: val_loss did not improve from 0.00015
# 100/100 [==============================] - 1s 8ms/step - loss: 8.1952e-04 - val_loss: 3.5020e-04
# Epoch 41/1000
#  94/100 [===========================>..] - ETA: 0s - loss: 8.1931e-04
# Epoch 00041: val_loss did not improve from 0.00015
# 100/100 [==============================] - 1s 8ms/step - loss: 8.1675e-04 - val_loss: 3.4876e-04
# Epoch 42/1000
#  93/100 [==========================>...] - ETA: 0s - loss: 0.0011
# Epoch 00042: val_loss did not improve from 0.00015
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0011 - val_loss: 2.3420e-04
# Epoch 43/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 9.8910e-04
# Epoch 00043: val_loss did not improve from 0.00015
# 100/100 [==============================] - 1s 8ms/step - loss: 9.6961e-04 - val_loss: 4.4820e-04
# Epoch 44/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 7.9987e-04
# Epoch 00044: val_loss did not improve from 0.00015
# 100/100 [==============================] - 1s 8ms/step - loss: 7.9609e-04 - val_loss: 5.8465e-04
# Epoch 45/1000
#  93/100 [==========================>...] - ETA: 0s - loss: 8.6238e-04
# Epoch 00045: val_loss did not improve from 0.00015
# 100/100 [==============================] - 1s 8ms/step - loss: 8.7557e-04 - val_loss: 9.7832e-04
# Epoch 46/1000
#  91/100 [==========================>...] - ETA: 0s - loss: 9.4223e-04
# Epoch 00046: val_loss did not improve from 0.00015
# 100/100 [==============================] - 1s 8ms/step - loss: 9.2850e-04 - val_loss: 3.9632e-04
# Epoch 47/1000
#  98/100 [============================>.] - ETA: 0s - loss: 6.9172e-04
# Epoch 00047: val_loss did not improve from 0.00015
# 100/100 [==============================] - 1s 8ms/step - loss: 6.9605e-04 - val_loss: 5.2461e-04
# Epoch 48/1000
#  98/100 [============================>.] - ETA: 0s - loss: 9.2368e-04
# Epoch 00048: val_loss did not improve from 0.00015
# 100/100 [==============================] - 1s 8ms/step - loss: 9.2115e-04 - val_loss: 4.1194e-04
# Epoch 49/1000
#  91/100 [==========================>...] - ETA: 0s - loss: 0.0011
# Epoch 00049: val_loss did not improve from 0.00015
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0011 - val_loss: 7.5150e-04
# Epoch 50/1000
#  94/100 [===========================>..] - ETA: 0s - loss: 8.7126e-04
# Epoch 00050: val_loss did not improve from 0.00015
# 100/100 [==============================] - 1s 8ms/step - loss: 8.5595e-04 - val_loss: 2.4274e-04
# Epoch 51/1000
#  96/100 [===========================>..] - ETA: 0s - loss: 7.3439e-04
# Epoch 00051: val_loss did not improve from 0.00015
# 100/100 [==============================] - 1s 9ms/step - loss: 7.4391e-04 - val_loss: 4.6111e-04
# Epoch 52/1000
#  95/100 [===========================>..] - ETA: 0s - loss: 9.9208e-04
# Epoch 00052: val_loss improved from 0.00015 to 0.00012, saving model to new_transf_lr01\model_bestValLoss
# 100/100 [==============================] - 1s 9ms/step - loss: 9.7741e-04 - val_loss: 1.1548e-04
# Epoch 53/1000
#  99/100 [============================>.] - ETA: 0s - loss: 6.9921e-04
# Epoch 00053: val_loss did not improve from 0.00012
# 100/100 [==============================] - 1s 9ms/step - loss: 6.9711e-04 - val_loss: 2.1223e-04
# Epoch 54/1000
#  94/100 [===========================>..] - ETA: 0s - loss: 7.2102e-04
# Epoch 00054: val_loss did not improve from 0.00012
# 100/100 [==============================] - 1s 9ms/step - loss: 7.0980e-04 - val_loss: 1.6190e-04
# Epoch 55/1000
#  99/100 [============================>.] - ETA: 0s - loss: 6.4315e-04
# Epoch 00055: val_loss did not improve from 0.00012
# 100/100 [==============================] - 1s 8ms/step - loss: 6.4243e-04 - val_loss: 2.3896e-04
# Epoch 56/1000
#  98/100 [============================>.] - ETA: 0s - loss: 0.0010
# Epoch 00056: val_loss did not improve from 0.00012
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0010 - val_loss: 3.0901e-04
# Epoch 57/1000
#  98/100 [============================>.] - ETA: 0s - loss: 7.0341e-04
# Epoch 00057: val_loss did not improve from 0.00012
# 100/100 [==============================] - 1s 8ms/step - loss: 7.0244e-04 - val_loss: 2.0702e-04
# Epoch 58/1000
#  94/100 [===========================>..] - ETA: 0s - loss: 5.4510e-04
# Epoch 00058: val_loss improved from 0.00012 to 0.00010, saving model to new_transf_lr01\model_bestValLoss
# 100/100 [==============================] - 1s 9ms/step - loss: 5.3930e-04 - val_loss: 1.0474e-04
# Epoch 59/1000
#  95/100 [===========================>..] - ETA: 0s - loss: 8.7684e-04
# Epoch 00059: val_loss did not improve from 0.00010
# 100/100 [==============================] - 1s 8ms/step - loss: 8.7977e-04 - val_loss: 6.0394e-04
# Epoch 60/1000
#  94/100 [===========================>..] - ETA: 0s - loss: 9.1605e-04
# Epoch 00060: val_loss did not improve from 0.00010
# 100/100 [==============================] - 1s 9ms/step - loss: 9.0366e-04 - val_loss: 8.5878e-04
# Epoch 61/1000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 00061: val_loss did not improve from 0.00010
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0012 - val_loss: 4.0326e-04
# Epoch 62/1000
#  91/100 [==========================>...] - ETA: 0s - loss: 7.7938e-04
# Epoch 00062: val_loss did not improve from 0.00010
# 100/100 [==============================] - 1s 8ms/step - loss: 7.8266e-04 - val_loss: 2.9765e-04
# Epoch 63/1000
#  98/100 [============================>.] - ETA: 0s - loss: 6.7473e-04
# Epoch 00063: val_loss did not improve from 0.00010
# 100/100 [==============================] - 1s 9ms/step - loss: 6.7135e-04 - val_loss: 3.0286e-04
# Epoch 64/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 5.3975e-04
# Epoch 00064: val_loss did not improve from 0.00010
# 100/100 [==============================] - 1s 8ms/step - loss: 5.3487e-04 - val_loss: 3.3506e-04
# Epoch 65/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 4.7432e-04
# Epoch 00065: val_loss did not improve from 0.00010
# 100/100 [==============================] - 1s 8ms/step - loss: 4.8531e-04 - val_loss: 4.2083e-04
# Epoch 66/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 6.9309e-04
# Epoch 00066: val_loss did not improve from 0.00010
# 100/100 [==============================] - 1s 9ms/step - loss: 7.0151e-04 - val_loss: 7.0145e-04
# Epoch 67/1000
#  98/100 [============================>.] - ETA: 0s - loss: 8.7909e-04
# Epoch 00067: val_loss did not improve from 0.00010
# 100/100 [==============================] - 1s 9ms/step - loss: 8.8143e-04 - val_loss: 2.2663e-04
# Epoch 68/1000
#  99/100 [============================>.] - ETA: 0s - loss: 7.3900e-04
# Epoch 00068: val_loss did not improve from 0.00010
# 100/100 [==============================] - 1s 8ms/step - loss: 7.3953e-04 - val_loss: 4.0165e-04
# Epoch 69/1000
#  99/100 [============================>.] - ETA: 0s - loss: 5.0125e-04
# Epoch 00069: val_loss did not improve from 0.00010
# 100/100 [==============================] - 1s 8ms/step - loss: 5.0011e-04 - val_loss: 2.4032e-04
# Epoch 70/1000
#  94/100 [===========================>..] - ETA: 0s - loss: 5.6147e-04
# Epoch 00070: val_loss did not improve from 0.00010
# 100/100 [==============================] - 1s 8ms/step - loss: 5.5881e-04 - val_loss: 2.4115e-04
# Epoch 71/1000
#  97/100 [============================>.] - ETA: 0s - loss: 9.0267e-04
# Epoch 00071: val_loss did not improve from 0.00010
# 100/100 [==============================] - 1s 9ms/step - loss: 8.9073e-04 - val_loss: 1.8739e-04
# Epoch 72/1000
#  98/100 [============================>.] - ETA: 0s - loss: 5.1652e-04
# Epoch 00072: val_loss did not improve from 0.00010
# 100/100 [==============================] - 1s 8ms/step - loss: 5.1680e-04 - val_loss: 4.4596e-04
# Epoch 73/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 7.0543e-04
# Epoch 00073: val_loss did not improve from 0.00010
# 100/100 [==============================] - 1s 9ms/step - loss: 7.7686e-04 - val_loss: 5.4420e-04
# Epoch 74/1000
#  99/100 [============================>.] - ETA: 0s - loss: 7.7046e-04
# Epoch 00074: val_loss did not improve from 0.00010
# 100/100 [==============================] - 1s 9ms/step - loss: 7.6942e-04 - val_loss: 3.2532e-04
# Epoch 75/1000
#  91/100 [==========================>...] - ETA: 0s - loss: 5.0695e-04
# Epoch 00075: val_loss did not improve from 0.00010
# 100/100 [==============================] - 1s 8ms/step - loss: 5.2175e-04 - val_loss: 4.7245e-04
# Epoch 76/1000
#  96/100 [===========================>..] - ETA: 0s - loss: 4.8255e-04
# Epoch 00076: val_loss did not improve from 0.00010
# 100/100 [==============================] - 1s 8ms/step - loss: 4.7978e-04 - val_loss: 3.7378e-04
# Epoch 77/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 5.0695e-04
# Epoch 00077: val_loss did not improve from 0.00010
# 100/100 [==============================] - 1s 9ms/step - loss: 5.1081e-04 - val_loss: 4.5491e-04
# Epoch 78/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 6.2082e-04
# Epoch 00078: val_loss did not improve from 0.00010
# 100/100 [==============================] - 1s 8ms/step - loss: 6.1066e-04 - val_loss: 1.3435e-04
# Epoch 79/1000
#  95/100 [===========================>..] - ETA: 0s - loss: 5.6171e-04
# Epoch 00079: val_loss did not improve from 0.00010
# 100/100 [==============================] - 1s 9ms/step - loss: 5.7100e-04 - val_loss: 2.9156e-04
# Epoch 80/1000
#  97/100 [============================>.] - ETA: 0s - loss: 6.0173e-04
# Epoch 00080: val_loss did not improve from 0.00010
# 100/100 [==============================] - 1s 8ms/step - loss: 5.9737e-04 - val_loss: 1.3014e-04
# Epoch 81/1000
#  96/100 [===========================>..] - ETA: 0s - loss: 4.5496e-04
# Epoch 00081: val_loss did not improve from 0.00010
# 100/100 [==============================] - 1s 9ms/step - loss: 4.5170e-04 - val_loss: 2.5672e-04
# Epoch 82/1000
#  98/100 [============================>.] - ETA: 0s - loss: 4.5655e-04
# Epoch 00082: val_loss did not improve from 0.00010
# 100/100 [==============================] - 1s 9ms/step - loss: 4.5720e-04 - val_loss: 5.8661e-04
# Epoch 83/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 4.4222e-04
# Epoch 00083: val_loss did not improve from 0.00010
# 100/100 [==============================] - 1s 8ms/step - loss: 4.4389e-04 - val_loss: 3.9245e-04
# Epoch 84/1000
#  95/100 [===========================>..] - ETA: 0s - loss: 4.3711e-04
# Epoch 00084: val_loss improved from 0.00010 to 0.00006, saving model to new_transf_lr01\model_bestValLoss
# 100/100 [==============================] - 1s 9ms/step - loss: 4.4442e-04 - val_loss: 5.6785e-05
# Epoch 85/1000
#  99/100 [============================>.] - ETA: 0s - loss: 4.9970e-04
# Epoch 00085: val_loss did not improve from 0.00006
# 100/100 [==============================] - 1s 8ms/step - loss: 5.0272e-04 - val_loss: 2.3708e-04
# Epoch 86/1000
#  91/100 [==========================>...] - ETA: 0s - loss: 5.6651e-04
# Epoch 00086: val_loss did not improve from 0.00006
# 100/100 [==============================] - 1s 9ms/step - loss: 5.7104e-04 - val_loss: 1.5290e-04
# Epoch 87/1000
#  98/100 [============================>.] - ETA: 0s - loss: 5.5170e-04
# Epoch 00087: val_loss did not improve from 0.00006
# 100/100 [==============================] - 1s 8ms/step - loss: 5.4803e-04 - val_loss: 1.9212e-04
# Epoch 88/1000
#  99/100 [============================>.] - ETA: 0s - loss: 5.2151e-04
# Epoch 00088: val_loss did not improve from 0.00006
# 100/100 [==============================] - 1s 9ms/step - loss: 5.2014e-04 - val_loss: 2.3608e-04
# Epoch 89/1000
#  97/100 [============================>.] - ETA: 0s - loss: 4.6220e-04
# Epoch 00089: val_loss did not improve from 0.00006
# 100/100 [==============================] - 1s 9ms/step - loss: 4.7399e-04 - val_loss: 7.8551e-04
# Epoch 90/1000
#  94/100 [===========================>..] - ETA: 0s - loss: 5.6788e-04
# Epoch 00090: val_loss did not improve from 0.00006
# 100/100 [==============================] - 1s 8ms/step - loss: 5.6429e-04 - val_loss: 4.8886e-04
# Epoch 91/1000
#  98/100 [============================>.] - ETA: 0s - loss: 6.8020e-04
# Epoch 00091: val_loss did not improve from 0.00006
# 100/100 [==============================] - 1s 9ms/step - loss: 6.7364e-04 - val_loss: 3.9717e-04
# Epoch 92/1000
#  94/100 [===========================>..] - ETA: 0s - loss: 4.4091e-04
# Epoch 00092: val_loss did not improve from 0.00006
# 100/100 [==============================] - 1s 8ms/step - loss: 4.4336e-04 - val_loss: 1.1729e-04
# Epoch 93/1000
#  98/100 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 00093: val_loss did not improve from 0.00006
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0011 - val_loss: 3.6672e-04
# Epoch 94/1000
#  94/100 [===========================>..] - ETA: 0s - loss: 5.7748e-04
# Epoch 00094: val_loss did not improve from 0.00006
# 100/100 [==============================] - 1s 9ms/step - loss: 5.7226e-04 - val_loss: 3.5108e-04
# Epoch 95/1000
#  99/100 [============================>.] - ETA: 0s - loss: 4.1533e-04
# Epoch 00095: val_loss did not improve from 0.00006
# 100/100 [==============================] - 1s 8ms/step - loss: 4.1432e-04 - val_loss: 1.3130e-04
# Epoch 96/1000
#  98/100 [============================>.] - ETA: 0s - loss: 4.0935e-04
# Epoch 00096: val_loss did not improve from 0.00006
# 100/100 [==============================] - 1s 9ms/step - loss: 4.1379e-04 - val_loss: 4.7163e-04
# Epoch 97/1000
#  93/100 [==========================>...] - ETA: 0s - loss: 0.0010
# Epoch 00097: val_loss did not improve from 0.00006
# 100/100 [==============================] - 1s 8ms/step - loss: 9.7739e-04 - val_loss: 1.3367e-04
# Epoch 98/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 3.6872e-04
# Epoch 00098: val_loss did not improve from 0.00006
# 100/100 [==============================] - 1s 8ms/step - loss: 3.6395e-04 - val_loss: 8.7396e-05
# Epoch 99/1000
#  97/100 [============================>.] - ETA: 0s - loss: 3.7335e-04
# Epoch 00099: val_loss did not improve from 0.00006
# 100/100 [==============================] - 1s 9ms/step - loss: 3.7925e-04 - val_loss: 2.6109e-04
# Epoch 100/1000
#  99/100 [============================>.] - ETA: 0s - loss: 5.1886e-04
# Epoch 00100: val_loss did not improve from 0.00006
# 100/100 [==============================] - 1s 9ms/step - loss: 5.1672e-04 - val_loss: 1.5106e-04
# Epoch 101/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 6.2072e-04
# Epoch 00101: val_loss did not improve from 0.00006
# 100/100 [==============================] - 1s 9ms/step - loss: 6.0819e-04 - val_loss: 2.9832e-04
# Epoch 102/1000
#  95/100 [===========================>..] - ETA: 0s - loss: 3.8895e-04
# Epoch 00102: val_loss did not improve from 0.00006
# 100/100 [==============================] - 1s 9ms/step - loss: 3.9114e-04 - val_loss: 1.5298e-04
# Epoch 103/1000
#  96/100 [===========================>..] - ETA: 0s - loss: 3.3537e-04
# Epoch 00103: val_loss did not improve from 0.00006
# 100/100 [==============================] - 1s 9ms/step - loss: 3.3478e-04 - val_loss: 8.6109e-05
# Epoch 104/1000
#  97/100 [============================>.] - ETA: 0s - loss: 3.1229e-04
# Epoch 00104: val_loss did not improve from 0.00006
# 100/100 [==============================] - 1s 8ms/step - loss: 3.1447e-04 - val_loss: 3.5446e-04
# Epoch 105/1000
#  97/100 [============================>.] - ETA: 0s - loss: 3.3105e-04
# Epoch 00105: val_loss did not improve from 0.00006
# 100/100 [==============================] - 1s 9ms/step - loss: 3.2789e-04 - val_loss: 3.8079e-04
# Epoch 106/1000
#  96/100 [===========================>..] - ETA: 0s - loss: 4.0776e-04
# Epoch 00106: val_loss did not improve from 0.00006
# 100/100 [==============================] - 1s 9ms/step - loss: 4.0653e-04 - val_loss: 1.4754e-04
# Epoch 107/1000
#  97/100 [============================>.] - ETA: 0s - loss: 4.1684e-04
# Epoch 00107: val_loss did not improve from 0.00006
# 100/100 [==============================] - 1s 8ms/step - loss: 4.2095e-04 - val_loss: 2.0821e-04
# Epoch 108/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 4.4165e-04
# Epoch 00108: val_loss did not improve from 0.00006
# 100/100 [==============================] - 1s 9ms/step - loss: 4.4089e-04 - val_loss: 3.6365e-04
# Epoch 109/1000
#  98/100 [============================>.] - ETA: 0s - loss: 3.4261e-04
# Epoch 00109: val_loss did not improve from 0.00006
# 100/100 [==============================] - 1s 8ms/step - loss: 3.4019e-04 - val_loss: 1.0800e-04
# Epoch 110/1000
#  97/100 [============================>.] - ETA: 0s - loss: 4.1583e-04
# Epoch 00110: val_loss did not improve from 0.00006
# 100/100 [==============================] - 1s 9ms/step - loss: 4.2063e-04 - val_loss: 5.5588e-04
# Epoch 111/1000
#  98/100 [============================>.] - ETA: 0s - loss: 4.6594e-04
# Epoch 00111: val_loss did not improve from 0.00006
# 100/100 [==============================] - 1s 9ms/step - loss: 4.7503e-04 - val_loss: 6.0590e-04
# Epoch 112/1000
#  99/100 [============================>.] - ETA: 0s - loss: 4.7567e-04
# Epoch 00112: val_loss did not improve from 0.00006
# 100/100 [==============================] - 1s 8ms/step - loss: 4.7390e-04 - val_loss: 3.6525e-04
# Epoch 113/1000
#  97/100 [============================>.] - ETA: 0s - loss: 3.9220e-04
# Epoch 00113: val_loss did not improve from 0.00006
# 100/100 [==============================] - 1s 9ms/step - loss: 3.9002e-04 - val_loss: 8.7131e-05
# Epoch 114/1000
#  91/100 [==========================>...] - ETA: 0s - loss: 3.6772e-04
# Epoch 00114: val_loss did not improve from 0.00006
# 100/100 [==============================] - 1s 8ms/step - loss: 3.8585e-04 - val_loss: 5.4014e-04
# Epoch 115/1000
#  99/100 [============================>.] - ETA: 0s - loss: 6.4288e-04
# Epoch 00115: val_loss did not improve from 0.00006
# 100/100 [==============================] - 1s 9ms/step - loss: 6.4098e-04 - val_loss: 5.7897e-04
# Epoch 116/1000
#  98/100 [============================>.] - ETA: 0s - loss: 3.9638e-04
# Epoch 00116: val_loss did not improve from 0.00006
# 100/100 [==============================] - 1s 9ms/step - loss: 3.9684e-04 - val_loss: 4.5982e-04
# Epoch 117/1000
#  98/100 [============================>.] - ETA: 0s - loss: 4.2384e-04
# Epoch 00117: val_loss did not improve from 0.00006
# 100/100 [==============================] - 1s 8ms/step - loss: 4.2264e-04 - val_loss: 9.9018e-05
# Epoch 118/1000
#  96/100 [===========================>..] - ETA: 0s - loss: 3.1952e-04
# Epoch 00118: val_loss did not improve from 0.00006
# 100/100 [==============================] - 1s 9ms/step - loss: 3.2297e-04 - val_loss: 5.3926e-04
# Epoch 119/1000
#  98/100 [============================>.] - ETA: 0s - loss: 3.5327e-04
# Epoch 00119: val_loss did not improve from 0.00006
# 100/100 [==============================] - 1s 9ms/step - loss: 3.5320e-04 - val_loss: 9.7533e-05
# Epoch 120/1000
#  93/100 [==========================>...] - ETA: 0s - loss: 6.6460e-04
# Epoch 00120: val_loss did not improve from 0.00006
# 100/100 [==============================] - 1s 8ms/step - loss: 6.4325e-04 - val_loss: 1.4665e-04
# Epoch 121/1000
#  95/100 [===========================>..] - ETA: 0s - loss: 3.3131e-04
# Epoch 00121: val_loss did not improve from 0.00006
# 100/100 [==============================] - 1s 9ms/step - loss: 3.2930e-04 - val_loss: 1.4646e-04
# Epoch 122/1000
#  99/100 [============================>.] - ETA: 0s - loss: 2.7908e-04
# Epoch 00122: val_loss improved from 0.00006 to 0.00005, saving model to new_transf_lr01\model_bestValLoss
# 100/100 [==============================] - 1s 9ms/step - loss: 2.7911e-04 - val_loss: 4.9894e-05
# Epoch 123/1000
#  95/100 [===========================>..] - ETA: 0s - loss: 3.2917e-04
# Epoch 00123: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 9ms/step - loss: 3.2942e-04 - val_loss: 2.7672e-04
# Epoch 124/1000
#  95/100 [===========================>..] - ETA: 0s - loss: 3.0567e-04
# Epoch 00124: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 9ms/step - loss: 3.1062e-04 - val_loss: 2.2306e-04
# Epoch 125/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 7.2210e-04
# Epoch 00125: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 8ms/step - loss: 7.0265e-04 - val_loss: 1.5640e-04
# Epoch 126/1000
#  98/100 [============================>.] - ETA: 0s - loss: 2.8550e-04
# Epoch 00126: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 9ms/step - loss: 2.8392e-04 - val_loss: 9.5627e-05
# Epoch 127/1000
#  99/100 [============================>.] - ETA: 0s - loss: 3.0253e-04
# Epoch 00127: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 8ms/step - loss: 3.0150e-04 - val_loss: 1.9587e-04
# Epoch 128/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 3.2246e-04
# Epoch 00128: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 10ms/step - loss: 3.4955e-04 - val_loss: 6.0599e-04
# Epoch 129/1000
#  99/100 [============================>.] - ETA: 0s - loss: 4.2441e-04
# Epoch 00129: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 8ms/step - loss: 4.2423e-04 - val_loss: 8.6713e-05
# Epoch 130/1000
#  99/100 [============================>.] - ETA: 0s - loss: 3.4642e-04
# Epoch 00130: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 9ms/step - loss: 3.4668e-04 - val_loss: 1.9905e-04
# Epoch 131/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 3.2931e-04
# Epoch 00131: val_loss improved from 0.00005 to 0.00005, saving model to new_transf_lr01\model_bestValLoss
# 100/100 [==============================] - 1s 9ms/step - loss: 3.2154e-04 - val_loss: 4.7040e-05
# Epoch 132/1000
#  99/100 [============================>.] - ETA: 0s - loss: 2.7720e-04
# Epoch 00132: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 9ms/step - loss: 2.7735e-04 - val_loss: 2.0625e-04
# Epoch 133/1000
#  95/100 [===========================>..] - ETA: 0s - loss: 3.5924e-04
# Epoch 00133: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 9ms/step - loss: 3.7770e-04 - val_loss: 7.8181e-04
# Epoch 134/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 3.7571e-04
# Epoch 00134: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 8ms/step - loss: 3.7573e-04 - val_loss: 2.6868e-04
# Epoch 135/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 5.5942e-04
# Epoch 00135: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 9ms/step - loss: 5.6807e-04 - val_loss: 7.6929e-04
# Epoch 136/1000
#  97/100 [============================>.] - ETA: 0s - loss: 5.0490e-04
# Epoch 00136: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 9ms/step - loss: 5.0278e-04 - val_loss: 1.2310e-04
# Epoch 137/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 3.0536e-04
# Epoch 00137: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 8ms/step - loss: 3.0998e-04 - val_loss: 3.5300e-04
# Epoch 138/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 3.7325e-04
# Epoch 00138: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 9ms/step - loss: 3.6324e-04 - val_loss: 8.5710e-05
# Epoch 139/1000
#  99/100 [============================>.] - ETA: 0s - loss: 2.4416e-04
# Epoch 00139: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 8ms/step - loss: 2.4526e-04 - val_loss: 1.2222e-04
# Epoch 140/1000
#  95/100 [===========================>..] - ETA: 0s - loss: 3.1785e-04
# Epoch 00140: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 9ms/step - loss: 3.1539e-04 - val_loss: 2.4706e-04
# Epoch 141/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 3.1745e-04
# Epoch 00141: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 9ms/step - loss: 3.0913e-04 - val_loss: 7.3616e-05
# Epoch 142/1000
#  96/100 [===========================>..] - ETA: 0s - loss: 2.5949e-04
# Epoch 00142: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 9ms/step - loss: 2.6306e-04 - val_loss: 4.1413e-04
# Epoch 143/1000
#  99/100 [============================>.] - ETA: 0s - loss: 5.5862e-04
# Epoch 00143: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 9ms/step - loss: 5.5515e-04 - val_loss: 1.2131e-04
# Epoch 144/1000
#  97/100 [============================>.] - ETA: 0s - loss: 4.2560e-04
# Epoch 00144: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 8ms/step - loss: 4.2048e-04 - val_loss: 1.6552e-04
# Epoch 145/1000
#  98/100 [============================>.] - ETA: 0s - loss: 2.9768e-04
# Epoch 00145: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 9ms/step - loss: 2.9551e-04 - val_loss: 1.8608e-04
# Epoch 146/1000
#  98/100 [============================>.] - ETA: 0s - loss: 3.7911e-04
# Epoch 00146: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 9ms/step - loss: 3.7626e-04 - val_loss: 8.2444e-05
# Epoch 147/1000
#  94/100 [===========================>..] - ETA: 0s - loss: 3.1618e-04
# Epoch 00147: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 8ms/step - loss: 3.1672e-04 - val_loss: 1.1364e-04
# Epoch 148/1000
#  99/100 [============================>.] - ETA: 0s - loss: 2.5012e-04
# Epoch 00148: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 9ms/step - loss: 2.5048e-04 - val_loss: 2.2894e-04
# Epoch 149/1000
#  96/100 [===========================>..] - ETA: 0s - loss: 2.5559e-04
# Epoch 00149: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 8ms/step - loss: 2.5651e-04 - val_loss: 1.7887e-04
# Epoch 150/1000
#  95/100 [===========================>..] - ETA: 0s - loss: 2.7899e-04
# Epoch 00150: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 9ms/step - loss: 2.7773e-04 - val_loss: 1.6130e-04
# Epoch 151/1000
#  99/100 [============================>.] - ETA: 0s - loss: 3.4588e-04
# Epoch 00151: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 8ms/step - loss: 3.4892e-04 - val_loss: 8.5810e-04
# Epoch 152/1000
#  95/100 [===========================>..] - ETA: 0s - loss: 3.9572e-04
# Epoch 00152: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 8ms/step - loss: 3.8958e-04 - val_loss: 1.8787e-04
# Epoch 153/1000
#  95/100 [===========================>..] - ETA: 0s - loss: 4.1008e-04
# Epoch 00153: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 9ms/step - loss: 4.0093e-04 - val_loss: 9.1874e-05
# Epoch 154/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 3.8422e-04
# Epoch 00154: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 8ms/step - loss: 3.8514e-04 - val_loss: 1.6954e-04
# Epoch 155/1000
#  93/100 [==========================>...] - ETA: 0s - loss: 2.9059e-04
# Epoch 00155: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 8ms/step - loss: 2.8362e-04 - val_loss: 6.5866e-05
# Epoch 156/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 2.4504e-04
# Epoch 00156: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 9ms/step - loss: 2.4758e-04 - val_loss: 5.9626e-05
# Epoch 157/1000
#  97/100 [============================>.] - ETA: 0s - loss: 2.6121e-04
# Epoch 00157: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 9ms/step - loss: 2.6048e-04 - val_loss: 1.8497e-04
# Epoch 158/1000
#  97/100 [============================>.] - ETA: 0s - loss: 3.1937e-04
# Epoch 00158: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 9ms/step - loss: 3.1808e-04 - val_loss: 1.8835e-04
# Epoch 159/1000
#  99/100 [============================>.] - ETA: 0s - loss: 2.6622e-04
# Epoch 00159: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 8ms/step - loss: 2.6500e-04 - val_loss: 2.6276e-04
# Epoch 160/1000
#  99/100 [============================>.] - ETA: 0s - loss: 2.4423e-04
# Epoch 00160: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 8ms/step - loss: 2.4367e-04 - val_loss: 2.0167e-04
# Epoch 161/1000
#  96/100 [===========================>..] - ETA: 0s - loss: 3.3745e-04
# Epoch 00161: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 9ms/step - loss: 3.4220e-04 - val_loss: 3.8321e-04
# Epoch 162/1000
#  99/100 [============================>.] - ETA: 0s - loss: 8.1861e-04
# Epoch 00162: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 8ms/step - loss: 8.1525e-04 - val_loss: 2.2459e-04
# Epoch 163/1000
#  97/100 [============================>.] - ETA: 0s - loss: 4.1676e-04
# Epoch 00163: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 9ms/step - loss: 4.1412e-04 - val_loss: 1.9810e-04
# Epoch 164/1000
#  93/100 [==========================>...] - ETA: 0s - loss: 2.8446e-04
# Epoch 00164: val_loss improved from 0.00005 to 0.00005, saving model to new_transf_lr01\model_bestValLoss
# 100/100 [==============================] - 1s 9ms/step - loss: 2.7848e-04 - val_loss: 4.6715e-05
# Epoch 165/1000
#  99/100 [============================>.] - ETA: 0s - loss: 2.2102e-04
# Epoch 00165: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 9ms/step - loss: 2.2060e-04 - val_loss: 1.9432e-04
# Epoch 166/1000
#  98/100 [============================>.] - ETA: 0s - loss: 2.3953e-04
# Epoch 00166: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 9ms/step - loss: 2.3774e-04 - val_loss: 8.0037e-05
# Epoch 167/1000
#  93/100 [==========================>...] - ETA: 0s - loss: 2.6337e-04
# Epoch 00167: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 8ms/step - loss: 2.6042e-04 - val_loss: 6.2184e-05
# Epoch 168/1000
#  98/100 [============================>.] - ETA: 0s - loss: 2.6066e-04
# Epoch 00168: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 9ms/step - loss: 2.5904e-04 - val_loss: 2.3840e-04
# Epoch 169/1000
#  91/100 [==========================>...] - ETA: 0s - loss: 2.2925e-04
# Epoch 00169: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 8ms/step - loss: 2.2688e-04 - val_loss: 1.2859e-04
# Epoch 170/1000
#  98/100 [============================>.] - ETA: 0s - loss: 2.4684e-04
# Epoch 00170: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 8ms/step - loss: 2.4521e-04 - val_loss: 9.7369e-05
# Epoch 171/1000
#  99/100 [============================>.] - ETA: 0s - loss: 2.3715e-04
# Epoch 00171: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 9ms/step - loss: 2.3632e-04 - val_loss: 1.9917e-04
# Epoch 172/1000
#  98/100 [============================>.] - ETA: 0s - loss: 3.0574e-04
# Epoch 00172: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 9ms/step - loss: 3.0500e-04 - val_loss: 5.9161e-05
# Epoch 173/1000
#  95/100 [===========================>..] - ETA: 0s - loss: 2.1558e-04
# Epoch 00173: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 9ms/step - loss: 2.1570e-04 - val_loss: 1.7900e-04
# Epoch 174/1000
#  98/100 [============================>.] - ETA: 0s - loss: 2.3448e-04
# Epoch 00174: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 8ms/step - loss: 2.3383e-04 - val_loss: 1.3311e-04
# Epoch 175/1000
#  98/100 [============================>.] - ETA: 0s - loss: 2.5170e-04
# Epoch 00175: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 9ms/step - loss: 2.4951e-04 - val_loss: 6.3582e-05
# Epoch 176/1000
#  95/100 [===========================>..] - ETA: 0s - loss: 3.0990e-04
# Epoch 00176: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 9ms/step - loss: 3.0924e-04 - val_loss: 1.5853e-04
# Epoch 177/1000
#  99/100 [============================>.] - ETA: 0s - loss: 2.5743e-04
# Epoch 00177: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 8ms/step - loss: 2.5668e-04 - val_loss: 8.1981e-05
# Epoch 178/1000
#  98/100 [============================>.] - ETA: 0s - loss: 2.3851e-04
# Epoch 00178: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 9ms/step - loss: 2.3841e-04 - val_loss: 7.6639e-05
# Epoch 179/1000
#  96/100 [===========================>..] - ETA: 0s - loss: 3.1769e-04
# Epoch 00179: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 9ms/step - loss: 3.1625e-04 - val_loss: 2.0504e-04
# Epoch 180/1000
#  98/100 [============================>.] - ETA: 0s - loss: 2.4892e-04
# Epoch 00180: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 8ms/step - loss: 2.4780e-04 - val_loss: 9.7471e-05
# Epoch 181/1000
#  93/100 [==========================>...] - ETA: 0s - loss: 3.3176e-04
# Epoch 00181: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 9ms/step - loss: 3.3190e-04 - val_loss: 4.0052e-04
# Epoch 182/1000
#  99/100 [============================>.] - ETA: 0s - loss: 5.1673e-04
# Epoch 00182: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 8ms/step - loss: 5.1363e-04 - val_loss: 5.6925e-05
# Epoch 183/1000
#  95/100 [===========================>..] - ETA: 0s - loss: 2.5902e-04
# Epoch 00183: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 9ms/step - loss: 2.5752e-04 - val_loss: 6.9241e-05
# Epoch 184/1000
#  97/100 [============================>.] - ETA: 0s - loss: 2.1328e-04
# Epoch 00184: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 8ms/step - loss: 2.1388e-04 - val_loss: 1.8603e-04
# Epoch 185/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 3.7749e-04
# Epoch 00185: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 8ms/step - loss: 4.0754e-04 - val_loss: 4.5196e-04
# Epoch 186/1000
#  96/100 [===========================>..] - ETA: 0s - loss: 4.0233e-04
# Epoch 00186: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 9ms/step - loss: 3.9205e-04 - val_loss: 5.6386e-05
# Epoch 187/1000
#  93/100 [==========================>...] - ETA: 0s - loss: 2.2145e-04
# Epoch 00187: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 8ms/step - loss: 2.2007e-04 - val_loss: 8.5131e-05
# Epoch 188/1000
#  93/100 [==========================>...] - ETA: 0s - loss: 1.9268e-04
# Epoch 00188: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 9ms/step - loss: 1.9408e-04 - val_loss: 1.1939e-04
# Epoch 189/1000
#  98/100 [============================>.] - ETA: 0s - loss: 1.8862e-04
# Epoch 00189: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 8ms/step - loss: 1.8723e-04 - val_loss: 5.7835e-05
# Epoch 190/1000
#  99/100 [============================>.] - ETA: 0s - loss: 2.1890e-04
# Epoch 00190: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 9ms/step - loss: 2.1912e-04 - val_loss: 1.2663e-04
# Epoch 191/1000
#  98/100 [============================>.] - ETA: 0s - loss: 1.9372e-04
# Epoch 00191: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 8ms/step - loss: 1.9364e-04 - val_loss: 1.8689e-04
# Epoch 192/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 1.9457e-04
# Epoch 00192: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 8ms/step - loss: 2.0033e-04 - val_loss: 1.5426e-04
# Epoch 193/1000
#  95/100 [===========================>..] - ETA: 0s - loss: 2.8198e-04
# Epoch 00193: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 9ms/step - loss: 2.7868e-04 - val_loss: 9.0993e-05
# Epoch 194/1000
#  93/100 [==========================>...] - ETA: 0s - loss: 2.0843e-04
# Epoch 00194: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 8ms/step - loss: 2.0422e-04 - val_loss: 7.3781e-05
# Epoch 195/1000
#  93/100 [==========================>...] - ETA: 0s - loss: 1.8377e-04
# Epoch 00195: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 8ms/step - loss: 1.9343e-04 - val_loss: 6.3379e-05
# Epoch 196/1000
#  98/100 [============================>.] - ETA: 0s - loss: 1.9438e-04
# Epoch 00196: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 8ms/step - loss: 1.9391e-04 - val_loss: 8.0891e-05
# Epoch 197/1000
#  99/100 [============================>.] - ETA: 0s - loss: 1.9536e-04
# Epoch 00197: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 8ms/step - loss: 1.9477e-04 - val_loss: 1.4643e-04
# Epoch 198/1000
#  98/100 [============================>.] - ETA: 0s - loss: 3.3542e-04
# Epoch 00198: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 8ms/step - loss: 3.3425e-04 - val_loss: 1.3050e-04
# Epoch 199/1000
#  93/100 [==========================>...] - ETA: 0s - loss: 2.4191e-04
# Epoch 00199: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 8ms/step - loss: 2.3699e-04 - val_loss: 6.9486e-05
# Epoch 200/1000
#  97/100 [============================>.] - ETA: 0s - loss: 1.9866e-04
# Epoch 00200: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 9ms/step - loss: 1.9788e-04 - val_loss: 1.3749e-04
# Epoch 201/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 1.6928e-04
# Epoch 00201: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 8ms/step - loss: 1.6868e-04 - val_loss: 5.6885e-05
# Epoch 202/1000
#  99/100 [============================>.] - ETA: 0s - loss: 1.6312e-04
# Epoch 00202: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 8ms/step - loss: 1.6351e-04 - val_loss: 8.9121e-05
# Epoch 203/1000
#  95/100 [===========================>..] - ETA: 0s - loss: 1.9602e-04
# Epoch 00203: val_loss did not improve from 0.00005
# 100/100 [==============================] - 1s 9ms/step - loss: 1.9922e-04 - val_loss: 8.9396e-05
# Epoch 204/1000
#  95/100 [===========================>..] - ETA: 0s - loss: 2.1386e-04
# Epoch 00204: val_loss did not improve from 0.00005
# ...
# 100/100 [==============================] - 1s 9ms/step - loss: 1.2465e-04 - val_loss: 4.2126e-05
# Epoch 254/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 1.8516e-04
# Epoch 00254: val_loss did not improve from 0.00003
# 100/100 [==============================] - 1s 8ms/step - loss: 2.9895e-04 - val_loss: 8.2378e-04
# Epoch 255/1000
#  94/100 [===========================>..] - ETA: 0s - loss: 8.2065e-04
# Epoch 00255: val_loss did not improve from 0.00003
# 100/100 [==============================] - 1s 10ms/step - loss: 7.8329e-04 - val_loss: 1.1116e-04
# Epoch 256/1000
#  99/100 [============================>.] - ETA: 0s - loss: 1.9008e-04
# Epoch 00256: val_loss did not improve from 0.00003
# 100/100 [==============================] - 1s 8ms/step - loss: 1.9116e-04 - val_loss: 3.9729e-05
# Epoch 257/1000
#  99/100 [============================>.] - ETA: 0s - loss: 1.9876e-04
# Epoch 00257: val_loss did not improve from 0.00003
# 100/100 [==============================] - 1s 9ms/step - loss: 1.9826e-04 - val_loss: 1.8403e-04
# Epoch 258/1000
#  95/100 [===========================>..] - ETA: 0s - loss: 1.7004e-04
# Epoch 00258: val_loss did not improve from 0.00003
# 100/100 [==============================] - 1s 9ms/step - loss: 1.6924e-04 - val_loss: 8.7067e-05
# Epoch 259/1000
#  94/100 [===========================>..] - ETA: 0s - loss: 1.6387e-04
# Epoch 00259: val_loss improved from 0.00003 to 0.00002, saving model to new_transf_lr01\model_bestValLoss
# 100/100 [==============================] - 1s 9ms/step - loss: 1.5912e-04 - val_loss: 2.0700e-05
# Epoch 260/1000
#  98/100 [============================>.] - ETA: 0s - loss: 1.3286e-04
# Epoch 00260: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 9ms/step - loss: 1.3401e-04 - val_loss: 3.6276e-05
# Epoch 261/1000
#  97/100 [============================>.] - ETA: 0s - loss: 2.2017e-04
# Epoch 00261: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 9ms/step - loss: 2.1764e-04 - val_loss: 9.1109e-05
# Epoch 262/1000
#  99/100 [============================>.] - ETA: 0s - loss: 1.5220e-04
# Epoch 00262: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 9ms/step - loss: 1.5268e-04 - val_loss: 9.8939e-05
# Epoch 263/1000
#  97/100 [============================>.] - ETA: 0s - loss: 1.1952e-04
# Epoch 00263: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 9ms/step - loss: 1.2085e-04 - val_loss: 5.3313e-05
# Epoch 264/1000
#  91/100 [==========================>...] - ETA: 0s - loss: 1.3530e-04
# Epoch 00264: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 8ms/step - loss: 1.3288e-04 - val_loss: 4.4245e-05
# Epoch 265/1000
#  99/100 [============================>.] - ETA: 0s - loss: 1.7635e-04
# Epoch 00265: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 9ms/step - loss: 1.7628e-04 - val_loss: 9.0013e-05
# Epoch 266/1000
#  98/100 [============================>.] - ETA: 0s - loss: 1.8630e-04
# Epoch 00266: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 8ms/step - loss: 1.8656e-04 - val_loss: 7.7444e-05
# Epoch 267/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 1.4420e-04
# Epoch 00267: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 9ms/step - loss: 1.4436e-04 - val_loss: 5.9051e-05
# Epoch 268/1000
#  96/100 [===========================>..] - ETA: 0s - loss: 1.4684e-04
# Epoch 00268: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 9ms/step - loss: 1.4424e-04 - val_loss: 2.3689e-05
# Epoch 269/1000
#  98/100 [============================>.] - ETA: 0s - loss: 1.2480e-04
# Epoch 00269: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 9ms/step - loss: 1.2590e-04 - val_loss: 1.4057e-04
# Epoch 270/1000
#  99/100 [============================>.] - ETA: 0s - loss: 1.5136e-04
# Epoch 00270: val_loss improved from 0.00002 to 0.00002, saving model to new_transf_lr01\model_bestValLoss
# 100/100 [==============================] - 1s 9ms/step - loss: 1.5104e-04 - val_loss: 1.9264e-05
# Epoch 271/1000
#  97/100 [============================>.] - ETA: 0s - loss: 1.1609e-04
# Epoch 00271: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 9ms/step - loss: 1.2097e-04 - val_loss: 7.1983e-05
# Epoch 272/1000
#  96/100 [===========================>..] - ETA: 0s - loss: 1.7229e-04
# Epoch 00272: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 9ms/step - loss: 1.7077e-04 - val_loss: 5.6232e-05
# Epoch 273/1000
#  97/100 [============================>.] - ETA: 0s - loss: 1.4274e-04
# Epoch 00273: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 9ms/step - loss: 1.4146e-04 - val_loss: 1.1290e-04
# Epoch 274/1000
#  99/100 [============================>.] - ETA: 0s - loss: 1.0973e-04
# Epoch 00274: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 8ms/step - loss: 1.1022e-04 - val_loss: 1.2734e-04
# Epoch 275/1000
#  96/100 [===========================>..] - ETA: 0s - loss: 1.5418e-04
# Epoch 00275: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 9ms/step - loss: 1.5784e-04 - val_loss: 1.6360e-04
# Epoch 276/1000
#  97/100 [============================>.] - ETA: 0s - loss: 1.4954e-04
# Epoch 00276: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 9ms/step - loss: 1.4826e-04 - val_loss: 2.3645e-05
# Epoch 277/1000
#  99/100 [============================>.] - ETA: 0s - loss: 1.1197e-04
# Epoch 00277: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 8ms/step - loss: 1.1145e-04 - val_loss: 2.2078e-05
# Epoch 278/1000
#  99/100 [============================>.] - ETA: 0s - loss: 1.4418e-04
# Epoch 00278: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 9ms/step - loss: 1.4433e-04 - val_loss: 1.0475e-04
# Epoch 279/1000
#  98/100 [============================>.] - ETA: 0s - loss: 1.5221e-04
# Epoch 00279: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 8ms/step - loss: 1.5319e-04 - val_loss: 1.0043e-04
# Epoch 280/1000
#  93/100 [==========================>...] - ETA: 0s - loss: 1.7646e-04
# Epoch 00280: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 9ms/step - loss: 1.7865e-04 - val_loss: 1.1449e-04
# Epoch 281/1000
#  96/100 [===========================>..] - ETA: 0s - loss: 1.5086e-04
# Epoch 00281: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 9ms/step - loss: 1.4968e-04 - val_loss: 5.2258e-05
# Epoch 282/1000
#  99/100 [============================>.] - ETA: 0s - loss: 1.4333e-04
# Epoch 00282: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 8ms/step - loss: 1.4328e-04 - val_loss: 6.7380e-05
# Epoch 283/1000
#  99/100 [============================>.] - ETA: 0s - loss: 1.2618e-04
# Epoch 00283: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 9ms/step - loss: 1.2594e-04 - val_loss: 9.5335e-05
# Epoch 284/1000
#  93/100 [==========================>...] - ETA: 0s - loss: 1.6213e-04
# Epoch 00284: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 8ms/step - loss: 1.5763e-04 - val_loss: 7.8421e-05
# Epoch 285/1000
#  93/100 [==========================>...] - ETA: 0s - loss: 1.4876e-04
# Epoch 00285: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 9ms/step - loss: 1.4720e-04 - val_loss: 7.2164e-05
# Epoch 286/1000
#  99/100 [============================>.] - ETA: 0s - loss: 1.3648e-04
# Epoch 00286: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 8ms/step - loss: 1.3638e-04 - val_loss: 6.9203e-05
# Epoch 287/1000
#  99/100 [============================>.] - ETA: 0s - loss: 1.2890e-04
# Epoch 00287: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 8ms/step - loss: 1.2946e-04 - val_loss: 6.2408e-05
# Epoch 288/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 1.5618e-04
# Epoch 00288: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 9ms/step - loss: 1.6316e-04 - val_loss: 2.4075e-04
# Epoch 289/1000
#  94/100 [===========================>..] - ETA: 0s - loss: 1.8426e-04
# Epoch 00289: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 8ms/step - loss: 1.8228e-04 - val_loss: 6.5093e-05
# Epoch 290/1000
#  97/100 [============================>.] - ETA: 0s - loss: 1.5322e-04
# Epoch 00290: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 8ms/step - loss: 1.5432e-04 - val_loss: 9.0537e-05
# Epoch 291/1000
#  99/100 [============================>.] - ETA: 0s - loss: 1.1192e-04
# Epoch 00291: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 8ms/step - loss: 1.1147e-04 - val_loss: 3.4354e-05
# Epoch 292/1000
#  94/100 [===========================>..] - ETA: 0s - loss: 8.1420e-05
# Epoch 00292: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 8ms/step - loss: 8.0209e-05 - val_loss: 6.5102e-05
# Epoch 293/1000
#  96/100 [===========================>..] - ETA: 0s - loss: 7.9243e-05
# Epoch 00293: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 9ms/step - loss: 7.8936e-05 - val_loss: 3.5151e-05
# Epoch 294/1000
#  93/100 [==========================>...] - ETA: 0s - loss: 1.2052e-04
# Epoch 00294: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 8ms/step - loss: 1.2316e-04 - val_loss: 2.5392e-05
# Epoch 295/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 1.4222e-04
# Epoch 00295: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 9ms/step - loss: 1.4004e-04 - val_loss: 1.0292e-04
# Epoch 296/1000
#  91/100 [==========================>...] - ETA: 0s - loss: 1.4826e-04
# Epoch 00296: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 8ms/step - loss: 1.4930e-04 - val_loss: 6.5929e-05
# Epoch 297/1000
#  99/100 [============================>.] - ETA: 0s - loss: 9.6012e-05
# Epoch 00297: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 8ms/step - loss: 9.5621e-05 - val_loss: 2.1518e-05
# Epoch 298/1000
#  99/100 [============================>.] - ETA: 0s - loss: 9.5309e-05
# Epoch 00298: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 9ms/step - loss: 9.5018e-05 - val_loss: 4.6834e-05
# Epoch 299/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 1.0240e-04
# Epoch 00299: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 8ms/step - loss: 1.0089e-04 - val_loss: 3.4838e-05
# Epoch 300/1000
#  99/100 [============================>.] - ETA: 0s - loss: 1.4573e-04
# Epoch 00300: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 9ms/step - loss: 1.4482e-04 - val_loss: 4.9141e-05
# Epoch 301/1000
#  98/100 [============================>.] - ETA: 0s - loss: 1.0159e-04
# Epoch 00301: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 8ms/step - loss: 1.0147e-04 - val_loss: 6.1576e-05
# Epoch 302/1000
#  99/100 [============================>.] - ETA: 0s - loss: 1.7594e-04
# Epoch 00302: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 9ms/step - loss: 1.7451e-04 - val_loss: 7.4122e-05
# Epoch 303/1000
#  96/100 [===========================>..] - ETA: 0s - loss: 1.6532e-04
# Epoch 00303: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 9ms/step - loss: 1.6552e-04 - val_loss: 9.9830e-05
# Epoch 304/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 1.8063e-04
# Epoch 00304: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 8ms/step - loss: 1.7331e-04 - val_loss: 3.0158e-05
# Epoch 305/1000
#  97/100 [============================>.] - ETA: 0s - loss: 1.0364e-04
# Epoch 00305: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 9ms/step - loss: 1.0383e-04 - val_loss: 5.1834e-05
# Epoch 306/1000
#  96/100 [===========================>..] - ETA: 0s - loss: 1.4458e-04
# Epoch 00306: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 9ms/step - loss: 1.4751e-04 - val_loss: 9.5500e-05
# Epoch 307/1000
#  93/100 [==========================>...] - ETA: 0s - loss: 2.7192e-04
# Epoch 00307: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 9ms/step - loss: 2.6037e-04 - val_loss: 4.8676e-05
# Epoch 308/1000
#  94/100 [===========================>..] - ETA: 0s - loss: 1.7704e-04
# Epoch 00308: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 9ms/step - loss: 1.7573e-04 - val_loss: 7.2059e-05
# Epoch 309/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 1.2577e-04
# Epoch 00309: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 8ms/step - loss: 1.3097e-04 - val_loss: 1.5360e-04
# Epoch 310/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 1.5656e-04
# Epoch 00310: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 9ms/step - loss: 1.5570e-04 - val_loss: 5.5306e-05
# Epoch 311/1000
#  98/100 [============================>.] - ETA: 0s - loss: 2.6893e-04
# Epoch 00311: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 9ms/step - loss: 2.6658e-04 - val_loss: 5.3531e-05
# Epoch 312/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 1.4788e-04
# Epoch 00312: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 9ms/step - loss: 1.4271e-04 - val_loss: 3.8286e-05
# Epoch 313/1000
#  94/100 [===========================>..] - ETA: 0s - loss: 1.1587e-04
# Epoch 00313: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 9ms/step - loss: 1.1451e-04 - val_loss: 4.8872e-05
# Epoch 314/1000
#  91/100 [==========================>...] - ETA: 0s - loss: 1.2008e-04
# Epoch 00314: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 8ms/step - loss: 1.1664e-04 - val_loss: 3.9921e-05
# Epoch 315/1000
#  97/100 [============================>.] - ETA: 0s - loss: 8.6978e-05
# Epoch 00315: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 9ms/step - loss: 8.6640e-05 - val_loss: 3.0829e-05
# Epoch 316/1000
#  92/100 [==========================>...] - ETA: 0s - loss: 1.8853e-04
# Epoch 00316: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 8ms/step - loss: 2.6876e-04 - val_loss: 0.0012
# Epoch 317/1000
#  99/100 [============================>.] - ETA: 0s - loss: 2.9876e-04
# Epoch 00317: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 9ms/step - loss: 2.9707e-04 - val_loss: 1.5778e-04
# Epoch 318/1000
#  97/100 [============================>.] - ETA: 0s - loss: 1.4351e-04
# Epoch 00318: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 8ms/step - loss: 1.4276e-04 - val_loss: 3.9230e-05
# Epoch 319/1000
#  99/100 [============================>.] - ETA: 0s - loss: 1.9281e-04
# Epoch 00319: val_loss did not improve from 0.00002
# 100/100 [==============================] - 1s 8ms/step - loss: 1.9287e-04 - val_loss: 1.0763e-04
# Epoch 320/1000
#  98/100 [============================>.] - ETA: 0s - loss: 2.1141e-04
# Epoch 00320: val_loss did not improve from 0.00002
# Restoring model weights from the end of the best epoch.
# 100/100 [==============================] - 1s 10ms/step - loss: 2.0840e-04 - val_loss: 5.5277e-05
# Epoch 00320: early stopping
# INFO:tensorflow:Assets written to: new_transf_lr01\transformer_model\assets

# %% [markdown]
# # Evaluate model quality

# %% [markdown]
# ### Sample new data from environment and determine episode with most steps

# %%
dfEval = sample_data(episodes=100, seed=11)
dfEval.describe()
row_max_steps = dfEval[dfEval.step == dfEval.step.max()]
dfEval = dfEval[dfEval.episode==int(row_max_steps.episode)]

# %%
len(dfEval)
# Out:
# 67

# %% [markdown]
# ### Extract prediction bounds from training data

# %%
output_min = y_train_multi.min(axis=0)
output_max = y_train_multi.max(axis=0)
print ("min(output)_data: ", output_min)
print ("max(output)_data: ", output_max)
# Out:
# min(output)_data:  [-1.2681239  -3.02867    -0.20943902 -3.0405533 ]
# max(output)_data:  [2.3466897  2.9271307  0.20943895 3.164486  ]

# %% [markdown]
# # Evaluate Transformer

# %% [markdown]
# ### Evaluate neural network

# %%
import collections
modelpath = "new_transf_lr01"
# load model
# model = tf.keras.models.load_model(modelpath, compile=False)
transformer_model = TimeSeriesTransformer(num_layers=2, d_model=64, num_heads=4, dff=128, 
                              input_shape=input_shape, output_dim=len(mean_out), rate=0.1)
transformer_model.load_weights(f"{modelpath}/model_bestValLoss")
# model = tf.keras.models.load_model("new_model.bestValLoss", compile=False)
#model = tf.keras.models.load_model("model.h5.bestTrainLoss", compile=False)
#############################################################################
# in case of error: AttributeError: 'str' object has no attribute 'decode'
# => Downgrade h5py package to version 2.10.0: pip install h5py==2.10.0
#############################################################################

# FIFO-buffer that keeps the neural state
stateBuffer = collections.deque(maxlen=window_size)

# outputs of neural network will be stored here
transformer_transitions = []

for i in range (len(dfEval)): 
                            
    # estimation of first state
    if i < window_size: 
        state_data = np.float32([dfEval[CART_POS].values[i], dfEval[CART_VEL].values[i],
                               dfEval[PEND_POS].values[i], dfEval[PEND_VEL].values[i],
                               dfEval[ACTION].values[i]])
        stateBuffer.append(state_data)
        #print ("Filling initState: %s" % state_data)
    
    # predict successor state
    else: 
        
        ###########################
        # recall of neural network
        ###########################
        state = np.array([list(stateBuffer)])
        if i==5:
            print (state)
        netOutput = transformer_model.predict(np.float32(state))[0]
        
        # clip output to observed data bounds
        netOutput = np.clip(netOutput, output_min, output_max)
        
        # check if value bound was hit
        if np.any(netOutput == output_min) or np.any(netOutput == output_max):
            print ("Bound-hit at step: ", i, " => terminating further evaluation")
            break
        
        # append plotting data
        transformer_transitions.append ({
            CART_POS:netOutput[0], CART_VEL:netOutput[1],
            PEND_POS:netOutput[2], PEND_VEL:netOutput[3]
        })
        
        # update RNN state
        stateBuffer.append(np.float32([netOutput[0], netOutput[1], 
                                       netOutput[2], netOutput[3], 
                                       dfEval[ACTION].values[i]]))
        
dfNet_transformer = pd.DataFrame(transformer_transitions)
# Out:
# [[[-0.02343352 -0.15951891 -0.04575157  0.323499    0.        ]
#   [-0.0266239  -0.35396054 -0.03928159  0.60141     0.        ]
#   [-0.03370311 -0.5485116  -0.02725339  0.8814656   1.        ]
#   [-0.04437342 -0.35145396 -0.00758822  0.5786499   1.        ]]]
# Bound-hit at step:  56  => terminating further evaluation

# %% [markdown]
# ### Plot results

# %%
fig, axs = plt.subplots (5, 1, figsize=(10,10))

fields = [CART_POS, CART_VEL, PEND_POS, PEND_VEL]

for i in range (len(fields)):
    f = fields[i]
    axs[i].plot(range (len(dfNet_transformer)), dfEval[f].values[window_size:window_size+len(dfNet_transformer)], label=f)
    axs[i].plot(range (len(dfNet_transformer)), dfNet_transformer[f].values, label="prediction", ls="--")
    axs[i].grid()
    axs[i].legend(loc="best")
    
axs[4].plot(range (len(dfNet_transformer)), dfEval[ACTION].values[window_size:window_size+len(dfNet_transformer)], label=ACTION)
axs[4].grid()
axs[4].legend(loc="best")

# %% [markdown]
# ### LSTM

# %%
import collections
modelpath = "lstm_model"
# load model
model = tf.keras.models.load_model(os.path.join(modelpath, "lstm_model"), compile=False)
# model = tf.keras.models.load_model("new_model.bestValLoss", compile=False)
#model = tf.keras.models.load_model("model.h5.bestTrainLoss", compile=False)
#############################################################################
# in case of error: AttributeError: 'str' object has no attribute 'decode'
# => Downgrade h5py package to version 2.10.0: pip install h5py==2.10.0
#############################################################################

# FIFO-buffer that keeps the neural state
stateBuffer = collections.deque(maxlen=window_size)

# outputs of neural network will be stored here
lstm_transitions = []

for i in range (len(dfEval)): 
                            
    # estimation of first state
    if i < window_size: 
        state_data = np.float32([dfEval[CART_POS].values[i], dfEval[CART_VEL].values[i],
                               dfEval[PEND_POS].values[i], dfEval[PEND_VEL].values[i],
                               dfEval[ACTION].values[i]])
        stateBuffer.append(state_data)
        #print ("Filling initState: %s" % state_data)
    
    # predict successor state
    else: 
        
        ###########################
        # recall of neural network
        ###########################
        state = np.array([list(stateBuffer)])
        if i==5:
            print (state)
        netOutput = model.predict(np.float32(state))[0]
        
        # clip output to observed data bounds
        netOutput = np.clip(netOutput, output_min, output_max)
        
        # check if value bound was hit
        if np.any(netOutput == output_min) or np.any(netOutput == output_max):
            print ("Bound-hit at step: ", i, " => terminating further evaluation")
            break
        
        # append plotting data
        lstm_transitions.append ({
            CART_POS:netOutput[0], CART_VEL:netOutput[1],
            PEND_POS:netOutput[2], PEND_VEL:netOutput[3]
        })
        
        # update RNN state
        stateBuffer.append(np.float32([netOutput[0], netOutput[1], 
                                       netOutput[2], netOutput[3], 
                                       dfEval[ACTION].values[i]]))
        
dfNet_lstm = pd.DataFrame(lstm_transitions)
# Out:
# WARNING:tensorflow:From c:\Users\gulBa\CodingProjects\reinforcement-learning-project\TimeSeriesTransformer\.venv\lib\site-packages\tensorflow_core\python\ops\init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From c:\Users\gulBa\CodingProjects\reinforcement-learning-project\TimeSeriesTransformer\.venv\lib\site-packages\tensorflow_core\python\ops\init_ops.py:97: calling Orthogonal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From c:\Users\gulBa\CodingProjects\reinforcement-learning-project\TimeSeriesTransformer\.venv\lib\site-packages\tensorflow_core\python\ops\init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# [[[-0.02343352 -0.15951891 -0.04575157  0.323499    0.        ]
#   [-0.0266239  -0.35396054 -0.03928159  0.60141     0.        ]
#   [-0.03370311 -0.5485116  -0.02725339  0.8814656   1.        ]
#   [-0.04559917 -0.3538685  -0.00972465  0.5798856   1.        ]]]

# %%
fig, axs = plt.subplots (5, 1, figsize=(10,10))

fields = [CART_POS, CART_VEL, PEND_POS, PEND_VEL]

for i in range (len(fields)):
    f = fields[i]
    axs[i].plot(range (len(dfNet_lstm)), dfEval[f].values[window_size:window_size+len(dfNet_lstm)], label=f)
    axs[i].plot(range (len(dfNet_lstm)), dfNet_lstm[f].values, label="prediction", ls="--")
    axs[i].grid()
    axs[i].legend(loc="best")
    
axs[4].plot(range (len(dfNet_lstm)), dfEval[ACTION].values[window_size:window_size+len(dfNet_lstm)], label=ACTION)
axs[4].grid()
axs[4].legend(loc="best")

# %%
fig, axs = plt.subplots(4, 1, figsize=(12, 12))
fig.suptitle("Comparison of LSTM and Transformer Predictions", fontsize=16)

fields = [CART_POS, CART_VEL, PEND_POS, PEND_VEL]
titles = ["Cart Position", "Cart Velocity", "Pendulum Position", "Pendulum Velocity"]

for i in range(len(fields)):
    f = fields[i]
    axs[i].plot(range(len(dfNet_lstm)), dfEval[f].values[window_size:window_size+len(dfNet_lstm)], label=f"Observed {titles[i]}", color="blue")
    axs[i].plot(range(len(dfNet_lstm)), dfNet_lstm[f].values, label="LSTM Prediction", linestyle="--", color="orange")
    axs[i].plot(range(len(dfNet_transformer)), dfNet_transformer[f].values, label="Transformer Prediction", linestyle=":", color="green")
    axs[i].set_title(f"{titles[i]} Over Time")
    axs[i].set_xlabel("Time Steps")
    axs[i].set_ylabel(titles[i])
    axs[i].grid(True)
    axs[i].legend(loc="best")

plt.tight_layout(rect=[0, 0, 1, 0.96])  # Adjust layout to make room for the title
plt.show()
# Save the plot as an image file
plt.savefig("lstm_transformer_cartpole.png", dpi=300, bbox_inches='tight')

# %% [markdown]
# # Evaluation: Different Cartpole System Parameters
#
# e.g. length or mass

# %%
dfEval = sample_data(episodes=100, length=0.8)
dfEval.describe()
row_max_steps = dfEval[dfEval.step == dfEval.step.max()]
dfEval = dfEval[dfEval.episode==int(row_max_steps.episode)]

# %%
len(dfEval)
# Out:
# 88

# %%
output_min = y_train_multi.min(axis=0)
output_max = y_train_multi.max(axis=0)
print ("min(output)_data: ", output_min)
print ("max(output)_data: ", output_max)
# Out:
# min(output)_data:  [-1.2681239  -3.02867    -0.20943902 -3.0405533 ]
# max(output)_data:  [2.3466897  2.9271307  0.20943895 3.164486  ]

# %% [markdown]
# ## Transformer

# %%
import collections
modelpath = "new_transf_lr01"
# load model
# model = tf.keras.models.load_model(modelpath, compile=False)
transformer_model = TimeSeriesTransformer(num_layers=2, d_model=64, num_heads=4, dff=128, 
                              input_shape=input_shape, output_dim=len(mean_out), rate=0.1)
transformer_model.load_weights(f"{modelpath}/model_bestValLoss")
# model = tf.keras.models.load_model("new_model.bestValLoss", compile=False)
#model = tf.keras.models.load_model("model.h5.bestTrainLoss", compile=False)
#############################################################################
# in case of error: AttributeError: 'str' object has no attribute 'decode'
# => Downgrade h5py package to version 2.10.0: pip install h5py==2.10.0
#############################################################################

# FIFO-buffer that keeps the neural state
stateBuffer = collections.deque(maxlen=window_size)

# outputs of neural network will be stored here
transitions = []

for i in range (len(dfEval)): 
                            
    # estimation of first state
    if i < window_size: 
        state_data = np.float32([dfEval[CART_POS].values[i], dfEval[CART_VEL].values[i],
                               dfEval[PEND_POS].values[i], dfEval[PEND_VEL].values[i],
                               dfEval[ACTION].values[i]])
        stateBuffer.append(state_data)
        #print ("Filling initState: %s" % state_data)
    
    # predict successor state
    else: 
        
        ###########################
        # recall of neural network
        ###########################
        state = np.array([list(stateBuffer)])
        if i==5:
            print (state)
        netOutput = transformer_model.predict(np.float32(state))[0]
        
        # clip output to observed data bounds
        netOutput = np.clip(netOutput, output_min, output_max)
        
        # check if value bound was hit
        if np.any(netOutput == output_min) or np.any(netOutput == output_max):
            print ("Bound-hit at step: ", i, " => terminating further evaluation")
            break
        
        # append plotting data
        transitions.append ({
            CART_POS:netOutput[0], CART_VEL:netOutput[1],
            PEND_POS:netOutput[2], PEND_VEL:netOutput[3]
        })
        
        # update RNN state
        stateBuffer.append(np.float32([netOutput[0], netOutput[1], 
                                       netOutput[2], netOutput[3], 
                                       dfEval[ACTION].values[i]]))
        
dfNet_transformer = pd.DataFrame(transitions)
# Out:
# [[[-0.03553911  0.18906619 -0.01355786 -0.14170885  1.        ]
#   [-0.03175779  0.37931883 -0.01639204 -0.32728958  0.        ]
#   [-0.02417141  0.18933341 -0.02293783 -0.14762154  0.        ]
#   [-0.01775742 -0.0041539  -0.02555572  0.14177065  1.        ]]]
# Bound-hit at step:  53  => terminating further evaluation

# %% [markdown]
# ## LSTM

# %%
import collections
modelpath = "lstm_model"
# load model
model = tf.keras.models.load_model(os.path.join(modelpath, "lstm_model"), compile=False)
# model = tf.keras.models.load_model("new_model.bestValLoss", compile=False)
#model = tf.keras.models.load_model("model.h5.bestTrainLoss", compile=False)
#############################################################################
# in case of error: AttributeError: 'str' object has no attribute 'decode'
# => Downgrade h5py package to version 2.10.0: pip install h5py==2.10.0
#############################################################################

# FIFO-buffer that keeps the neural state
stateBuffer = collections.deque(maxlen=window_size)

# outputs of neural network will be stored here
transitions = []

for i in range (len(dfEval)): 
                            
    # estimation of first state
    if i < window_size: 
        state_data = np.float32([dfEval[CART_POS].values[i], dfEval[CART_VEL].values[i],
                               dfEval[PEND_POS].values[i], dfEval[PEND_VEL].values[i],
                               dfEval[ACTION].values[i]])
        stateBuffer.append(state_data)
        #print ("Filling initState: %s" % state_data)
    
    # predict successor state
    else: 
        
        ###########################
        # recall of neural network
        ###########################
        state = np.array([list(stateBuffer)])
        if i==5:
            print (state)
        netOutput = model.predict(np.float32(state))[0]
        
        # clip output to observed data bounds
        netOutput = np.clip(netOutput, output_min, output_max)
        
        # check if value bound was hit
        if np.any(netOutput == output_min) or np.any(netOutput == output_max):
            print ("Bound-hit at step: ", i, " => terminating further evaluation")
            break
        
        # append plotting data
        transitions.append ({
            CART_POS:netOutput[0], CART_VEL:netOutput[1],
            PEND_POS:netOutput[2], PEND_VEL:netOutput[3]
        })
        
        # update RNN state
        stateBuffer.append(np.float32([netOutput[0], netOutput[1], 
                                       netOutput[2], netOutput[3], 
                                       dfEval[ACTION].values[i]]))
        
dfNet_lstm = pd.DataFrame(transitions)
# Out:
# [[[-0.03553911  0.18906619 -0.01355786 -0.14170885  1.        ]
#   [-0.03175779  0.37931883 -0.01639204 -0.32728958  0.        ]
#   [-0.02417141  0.18933341 -0.02293783 -0.14762154  0.        ]
#   [-0.01838989 -0.00923247 -0.02547642  0.15431906  1.        ]]]
# Bound-hit at step:  47  => terminating further evaluation

# %%
fig, axs = plt.subplots(4, 1, figsize=(12, 12))
fig.suptitle("Comparison of LSTM and Transformer Predictions: Generalization to different Settings", fontsize=16)

fields = [CART_POS, CART_VEL, PEND_POS, PEND_VEL]
titles = ["Cart Position", "Cart Velocity", "Pendulum Position", "Pendulum Velocity"]

for i in range(len(fields)):
    f = fields[i]
    axs[i].plot(range(len(dfNet_transformer)), dfEval[f].values[window_size:window_size+len(dfNet_transformer)], label=f"Observed {titles[i]}", color="blue")
    axs[i].plot(range(len(dfNet_lstm)), dfNet_lstm[f].values, label="LSTM Prediction", linestyle="--", color="orange")
    axs[i].plot(range(len(dfNet_transformer)), dfNet_transformer[f].values, label="Transformer Prediction", linestyle=":", color="green")
    axs[i].set_title(f"{titles[i]} Over Time")
    axs[i].set_xlabel("Time Steps")
    axs[i].set_ylabel(titles[i])
    axs[i].grid(True)
    axs[i].legend(loc="best")

plt.tight_layout(rect=[0, 0, 1, 0.96])  # Adjust layout to make room for the title
plt.show()
# Save the plot as an image file
plt.savefig("lstm_transformer_cartpole_generalization.png", dpi=300, bbox_inches='tight')
